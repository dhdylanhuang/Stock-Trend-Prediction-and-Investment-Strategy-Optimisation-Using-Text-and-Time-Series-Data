# %% [markdown]
# # Benchmarking Results from Classification and Regression

# %% [markdown]
# #### Set Up

# %%
import pandas as pd
import numpy as np
import site
import os

# %%
# Preprocessing cache to avoid recomputing features/sequences/splits per trial
from collections import OrderedDict

USE_PREPROCESS_CACHE = True
CACHE_MAX_ITEMS = 256  # adjust if memory is tight
PREPROCESS_CACHE = OrderedDict()

def _cache_get(key):
    if not USE_PREPROCESS_CACHE:
        return None
    val = PREPROCESS_CACHE.get(key)
    if val is not None:
        PREPROCESS_CACHE.move_to_end(key)
        try:
            print(f"[CACHE HIT] key={key}")
        except Exception:
            print("[CACHE HIT] (key repr failed)")
    return val

def _cache_set(key, val):
    if not USE_PREPROCESS_CACHE:
        return
    PREPROCESS_CACHE[key] = val
    PREPROCESS_CACHE.move_to_end(key)
    if len(PREPROCESS_CACHE) > CACHE_MAX_ITEMS:
        PREPROCESS_CACHE.popitem(last=False)

# %%
from pathlib import Path

PERSIST_ROOT = Path(os.environ.get('PERSIST_ROOT', '/mnt/primary'))
if not PERSIST_ROOT.exists():
    raise RuntimeError(f'Persistent storage not found at {PERSIST_ROOT}. Check mounts (df -h /mnt/primary).')

RUN_ROOT = Path(os.environ.get('RUN_ROOT', PERSIST_ROOT / 'benchmarking'))
if not str(RUN_ROOT).startswith(str(PERSIST_ROOT)):
    print(f'WARNING: RUN_ROOT={RUN_ROOT} is not on persistent storage; forcing to {PERSIST_ROOT}/benchmarking')
    RUN_ROOT = PERSIST_ROOT / 'benchmarking'
RUN_ROOT.mkdir(parents=True, exist_ok=True)

DATA_PATH = Path(os.environ.get('DATA_PATH', RUN_ROOT / 'master_df_60rf.parquet'))
RESULTS_ROOT = Path(os.environ.get('RESULTS_ROOT', RUN_ROOT / 'meta-results'))
RESULTS_ROOT.mkdir(parents=True, exist_ok=True)

print('DATA_PATH:', DATA_PATH)
print('RESULTS_ROOT:', RESULTS_ROOT)
# Out:
# DATA_PATH: /mnt/primary/benchmarking/master_df_60rf.parquet
# RESULTS_ROOT: /mnt/primary/benchmarking/meta-results

# %%
# DataLoader tuning for 4 CPU cores
NUM_WORKERS_TRAIN = 2
NUM_WORKERS_EVAL = 2
PIN_MEMORY = True
PERSISTENT_WORKERS = True

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.utils.class_weight import compute_class_weight

from sklearn.metrics import (
    precision_score, recall_score, f1_score, matthews_corrcoef,
    mean_squared_error, mean_absolute_error, r2_score, confusion_matrix
)

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau
from contextlib import nullcontext

import random

from unicodedata import bidirectional

# %% [markdown]
# ### Utility Classes and Functions

# %%
def set_global_seeds(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_global_seeds(42)

# Datasets
class SequenceDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]


class RNNHead(nn.Module):
    # Shared head:
    #   - RNN stack (LSTM/GRU, uni/bi)
    #   - BatchNorm + Dense(32, ReLU) + Dropout
    #   - Output layer (1 unit): linear (regression) or logits (classification)
    def __init__(self, input_size, rnn_type='LSTM', bidirectional=False, problem_type='classification', 
                 hidden1=128, hidden2=64, num_layers=1,
                 inter_rnn_drop=0.1, dropout=0.3, use_layernorm=False):
        super().__init__()
        self.problem_type = problem_type
        self.bidirectional = bidirectional
        self.rnn_type = rnn_type.upper()
        self.num_layers = int(num_layers)
        self.hidden1 = int(hidden1)
        self.hidden2 = int(hidden2)

        if self.num_layers not in (1, 2):
            raise ValueError("num_layers must be 1 or 2")

        rnn_cls = {'LSTM': nn.LSTM, 'GRU': nn.GRU}[('GRU' if 'GRU' in self.rnn_type else 'LSTM')]

        self.rnn1 = rnn_cls(
            input_size=input_size, hidden_size=self.hidden1, num_layers=1,
            batch_first=True, dropout=0.0, bidirectional=bidirectional
        )

        self.inter_rnn_drop = nn.Dropout(float(inter_rnn_drop))

        self.rnn2 = None
        if self.num_layers == 2:
            self.rnn2 = rnn_cls(
                input_size=self.hidden1*(2 if bidirectional else 1), hidden_size=self.hidden2, num_layers=1,
                batch_first=True, dropout=0.0, bidirectional=bidirectional
            )
            feat_dim = self.hidden2*(2 if bidirectional else 1)
        else:
            feat_dim = self.hidden1*(2 if bidirectional else 1)

        if use_layernorm:
            self.bn = nn.LayerNorm(feat_dim)
        else:
            self.bn = nn.BatchNorm1d(feat_dim)
        self.fc = nn.Linear(feat_dim, 32)
        self.drop = nn.Dropout(float(dropout))
        self.out = nn.Linear(32, 1)

    def forward(self, x):
        # x: [B, T, F]
        out, _ = self.rnn1(x)
        if self.num_layers == 2:
            out = self.inter_rnn_drop(out)   # inter-layer dropout (sequence-wise)
            out, _ = self.rnn2(out)
        # take last timestep: [B, T, H] -> [B, H]
        out = out[:, -1, :]
        out = self.bn(out)
        out = F.relu(self.fc(out))
        out = self.drop(out)
        out = self.out(out)  # shape [B,1]
        return out  # regression: raw; classification: logits


def build_model(input_shape, model_type='LSTM', problem_type='regression', hidden1=128, hidden2=64, 
                num_layers=2, inter_rnn_drop=0.1, dropout=0.3, use_layernorm=False):
    seq_len, n_features = input_shape
    model_type = model_type.upper()
    kwargs = dict(
        problem_type=problem_type,
        hidden1=hidden1,
        hidden2=hidden2,
        num_layers=num_layers,
        inter_rnn_drop=inter_rnn_drop,
        dropout=dropout,
        use_layernorm=use_layernorm,
    )
    if model_type == 'LSTM':
        return RNNHead(n_features, rnn_type='LSTM', bidirectional=False, **kwargs)
    elif model_type == 'BILSTM':
        return RNNHead(n_features, rnn_type='LSTM', bidirectional=True, **kwargs)
    elif model_type == 'GRU':
        return RNNHead(n_features, rnn_type='GRU', bidirectional=False, **kwargs)
    elif model_type == 'BIGRU':
        return RNNHead(n_features, rnn_type='GRU', bidirectional=True, **kwargs)
    else:
        raise ValueError("Model type must be one of: ['LSTM','BiLSTM','GRU','BiGRU']")

# Early Stopping (PyTorch)
class EarlyStopper:
    def __init__(self, patience=15, min_delta=0.0, restore_best=True):
        self.patience = patience
        self.min_delta = min_delta
        self.restore_best = restore_best
        self.best_loss = float('inf')
        self.counter = 0
        self.best_state = None

    def step(self, val_loss, model):
        improved = (self.best_loss - val_loss) > self.min_delta
        if improved:
            self.best_loss = val_loss
            self.counter = 0
            if self.restore_best:
                # Deep copy state dict
                self.best_state = {k: v.detach().clone() for k, v in model.state_dict().items()}
        else:
            self.counter += 1
        return self.counter >= self.patience

    def restore(self, model):
        if self.restore_best and self.best_state is not None:
            model.load_state_dict(self.best_state)

# %%
def pct_return(series, h):
    return series.shift(-h) / series - 1.0

def best_threshold_from_val(y_true, y_scores, metric='f1', grid=None):
    """
    Sweep probability thresholds on validation scores to maximize a metric.
    metric can be 'f1', 'mcc', 'accuracy', or a callable(y_true,y_pred)->float.
    Returns (best_threshold, best_metric_value).
    """
    y_true = np.asarray(y_true).astype(int)
    y_scores = np.asarray(y_scores).astype(float)
    if grid is None:
        grid = np.linspace(0.05, 0.95, 181)
    metric_fn = None
    if callable(metric):
        metric_fn = metric
    else:
        name = str(metric).lower()
        if name == 'f1':
            metric_fn = lambda yt, yp: f1_score(yt, yp, zero_division=0)
        elif name == 'mcc':
            metric_fn = lambda yt, yp: matthews_corrcoef(yt, yp)
        elif name in ('acc', 'accuracy'):
            metric_fn = lambda yt, yp: (yt == yp).mean()
        else:
            raise ValueError(f"Unsupported metric '{metric}'")
    best_thr = 0.5
    best_val = -np.inf
    for thr in grid:
        preds = (y_scores >= thr).astype(int)
        val = metric_fn(y_true, preds)
        if val > best_val + 1e-12 or (abs(val - best_val) <= 1e-12 and thr < best_thr):
            best_val = float(val)
            best_thr = float(thr)
    return best_thr, best_val

# %% [markdown]
# ## Stock Prediction Pipeline

# %%
class StockPredictionPipeline:
    def __init__(self, df, feature_columns, model_type='LSTM', sequence_length=20, problem_type='regression', horizon_steps=1,
                 hidden1=64, hidden2=128, num_layers=1, inter_rnn_drop=0.4, dropout=0.7,
                 batch_size=16, learning_rate=4e-3, weight_decay=0, lr_patience=7, lr_factor=0.5,
                 early_stopping_patience=15, max_epochs=20, use_layernorm=False, huber_delta=1.66, 
                 early_stopping_min_delta=0.0, trial=None):
        self.df = df.copy()
        self.feature_columns = feature_columns
        self.model_type = model_type
        self.sequence_length = sequence_length
        self.problem_type = problem_type
        self.horizon_steps = horizon_steps
        self.results = []
        self.loss_curves = []
        self.skip_reasons = {}
        self.skipped_companies = []
        self.trial = trial
        self._trial_step = 0
        self.hidden1 = hidden1
        self.hidden2 = hidden2
        self.num_layers = num_layers
        self.inter_rnn_drop = inter_rnn_drop
        self.dropout = dropout
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.weight_decay = weight_decay
        self.lr_patience = lr_patience
        self.lr_factor = lr_factor
        self.early_stopping_patience = early_stopping_patience
        self.max_epochs = max_epochs
        self.use_layernorm = use_layernorm
        self.huber_delta = huber_delta
        self.early_stopping_min_delta = early_stopping_min_delta

        # Validate
        self._validate_inputs()

        # Device & precision
        if torch.cuda.is_available():
            self.device = torch.device('cuda')
        elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
            self.device = torch.device('mps')
        else:
            self.device = torch.device('cpu')
        self.mixed_precision = (self.device.type == 'cuda')

        print(f"Pipeline initialized for a '{self.problem_type}' problem "
              f"with horizon {self.horizon_steps} steps. Device: {self.device}")

    def _validate_inputs(self):
        missing_cols = [col for col in self.feature_columns if col not in self.df.columns]
        if missing_cols:
            raise ValueError(f"Missing feature columns: {missing_cols}")

        if not any(col in self.df.columns for col in ['adj_close', 'adj close', 'close', 'close_price']):
            raise ValueError("No 'adj_close'/'adj close'/'close' or 'close_price' column found in data")

        valid_models = ['LSTM', 'BiLSTM', 'GRU', 'BiGRU']
        if self.model_type not in valid_models:
            raise ValueError(f"Model type must be one of: {valid_models}")

        if self.problem_type not in ['regression', 'classification']:
            raise ValueError("Problem type must be 'regression' or 'classification'")

    def _record_skip(self, company_name, reason, sector=None):
        self.skip_reasons[reason] = self.skip_reasons.get(reason, 0) + 1
        self.skipped_companies.append({'company': company_name, 'sector': sector, 'reason': reason})

    def create_target_variable(self, company_data):
        company_data = company_data.copy()
        price_col = 'close' if 'close' in company_data.columns else 'close_price'
        if 'date' in company_data.columns:
            company_data = company_data.sort_values('date')

        h = self.horizon_steps

        company_data['target_regression'] = (
            np.log(company_data[price_col].shift(-h)) - np.log(company_data[price_col])
        )
        company_data['target_direction'] = (company_data['target_regression'] > 0).astype(int)
        company_data['ret_h'] = pct_return(company_data[price_col], h)
        company_data = company_data.dropna()
        return company_data

    def create_sequences(self, features, *targets):
        X = []
        y_sequences = [[] for _ in targets]
        for i in range(self.sequence_length, len(features)):
            X.append(features[i-self.sequence_length:i])
            for j, target in enumerate(targets):
                y_sequences[j].append(target[i])
        return (np.array(X),) + tuple(np.array(y) for y in y_sequences)

    def _train_one_epoch(self, model, loader, optimizer, loss_fn, scaler):
        model.train()
        total_loss = 0.0
        for xb, yb in loader:
            xb = xb.to(self.device)
            yb = yb.to(self.device).view(-1, 1)

            optimizer.zero_grad(set_to_none=True)

            ctx = torch.amp.autocast('cuda') if self.mixed_precision else nullcontext()
            with ctx:
                logits = model(xb)
                loss = loss_fn(logits, yb)

            if self.mixed_precision:
                scaler.scale(loss).backward()
                scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                scaler.step(optimizer)
                scaler.update()
            else:
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                optimizer.step()

            total_loss += loss.item() * xb.size(0)

        return total_loss / len(loader.dataset)

    @torch.no_grad()
    def _eval_one_epoch(self, model, loader, loss_fn):
        model.eval()
        total_loss = 0.0
        for xb, yb in loader:
            xb = xb.to(self.device)
            yb = yb.to(self.device).view(-1, 1)
            logits = model(xb)
            loss = loss_fn(logits, yb)
            total_loss += loss.item() * xb.size(0)
        return total_loss / len(loader.dataset)

    @torch.no_grad()
    def _predict(self, model, loader):
        model.eval()
        outs = []
        for xb, _ in loader:
            xb = xb.to(self.device)
            logits = model(xb).squeeze(1).detach().cpu().numpy()
            outs.append(logits)
        return np.concatenate(outs, axis=0)

    def build_model(self, input_shape):
        model = build_model(
            input_shape,
            model_type=self.model_type,
            problem_type=self.problem_type,
            hidden1=self.hidden1,
            hidden2=self.hidden2,
            num_layers=self.num_layers,
            inter_rnn_drop=self.inter_rnn_drop,
            dropout=self.dropout,
            use_layernorm=self.use_layernorm
        )
        return model.to(self.device)

    def _empty_cache(self):
        if self.device.type == 'cuda':
            torch.cuda.empty_cache()
        elif self.device.type == 'mps' and hasattr(torch, 'mps'):
            try:
                torch.mps.empty_cache()
            except Exception:
                pass

    def process_company(self, company_name, company_data, sector):
        print(f"\nProcessing {company_name} ({sector})...")
        try:
            # Fixed date windows (keep consistent with diagnostics)
            train_start = pd.Timestamp('2014-01-01')
            train_end = pd.Timestamp('2015-08-01')
            val_end = pd.Timestamp('2015-10-01')
            test_end = pd.Timestamp('2016-01-01')

            cache_key = (
                company_name,
                tuple(self.feature_columns),
                self.sequence_length,
                self.horizon_steps,
                train_start,
                train_end,
                val_end,
                test_end,
            )
            cached = _cache_get(cache_key)

            if cached is None:
                company_data = company_data.copy()
                if 'date' not in company_data.columns:
                    print(f"Missing date column for {company_name}. Skipping...")
                    self._record_skip(company_name, "missing_date", sector)
                    return None
                company_data['date'] = pd.to_datetime(company_data['date'], errors='coerce')
                company_data = company_data.dropna(subset=['date'])
                if company_data.empty:
                    print(f"No valid dates for {company_name}. Skipping...")
                    self._record_skip(company_name, "invalid_date", sector)
                    return None
                company_data = self.create_target_variable(company_data)

                # Min samples requirement (same heuristic)
                min_samples = self.sequence_length + self.horizon_steps + 60
                if len(company_data) < min_samples:
                    print(f"Insufficient data for {company_name} ({len(company_data)} < {min_samples}). Skipping...")
                    self._record_skip(company_name, "insufficient_data", sector)
                    return None

                if company_data[self.feature_columns].isnull().any().any():
                    print(f"Missing values in features for {company_name}. Skipping...")
                    self._record_skip(company_name, "missing_features", sector)
                    return None

                features = company_data[self.feature_columns].values
                target_reg = company_data['target_regression'].values
                target_dir = company_data['target_direction'].values

                # Create sequences
                X_raw, y_reg, y_dir = self.create_sequences(features, target_reg, target_dir)

                # Date-based split (fixed ranges)
                seq_end_dates = pd.to_datetime(company_data['date'].values[self.sequence_length:], errors='coerce')
                valid_dates_mask = ~pd.isna(seq_end_dates)
                if not valid_dates_mask.any():
                    print(f"No valid sequence dates for {company_name}. Skipping...")
                    self._record_skip(company_name, "no_seq_dates", sector)
                    return None

                # Apply valid date mask to sequences and targets
                X_raw = X_raw[valid_dates_mask]
                y_reg = y_reg[valid_dates_mask]
                y_dir = y_dir[valid_dates_mask]
                seq_end_dates = seq_end_dates[valid_dates_mask]

                train_mask = (seq_end_dates >= train_start) & (seq_end_dates < train_end)
                val_mask   = (seq_end_dates >= train_end) & (seq_end_dates < val_end)
                test_mask  = (seq_end_dates >= val_end) & (seq_end_dates < test_end)

                train_idx = np.where(train_mask)[0]
                val_idx   = np.where(val_mask)[0]
                test_idx  = np.where(test_mask)[0]

                if len(train_idx) == 0:
                    print(f"No training data in range for {company_name}. Skipping...")
                    self._record_skip(company_name, "no_train_window", sector)
                    return None
                if len(val_idx) == 0:
                    print(f"No validation data in range for {company_name}. Skipping...")
                    self._record_skip(company_name, "no_val_window", sector)
                    return None
                if len(test_idx) == 0:
                    print(f"No test data in range for {company_name}. Skipping...")
                    self._record_skip(company_name, "no_test_window", sector)
                    return None

                X_train_raw, X_val_raw, X_test_raw = X_raw[train_idx], X_raw[val_idx], X_raw[test_idx]

                F = X_raw.shape[-1]
                feat_scaler = StandardScaler()
                X_train = feat_scaler.fit_transform(X_train_raw.reshape(-1, F)).reshape(X_train_raw.shape)
                X_val   = feat_scaler.transform(X_val_raw.reshape(-1, F)).reshape(X_val_raw.shape)
                X_test  = feat_scaler.transform(X_test_raw.reshape(-1, F)).reshape(X_test_raw.shape)

                y_reg_train, y_reg_val, y_reg_test = y_reg[train_idx], y_reg[val_idx], y_reg[test_idx]
                y_dir_train, y_dir_val, y_dir_test = y_dir[train_idx], y_dir[val_idx], y_dir[test_idx]

                # Always fit target scaler once so regression can reuse it across trials
                target_scaler = StandardScaler()
                y_reg_train_scaled = target_scaler.fit_transform(y_reg_train.reshape(-1, 1)).flatten()
                y_reg_val_scaled   = target_scaler.transform(y_reg_val.reshape(-1, 1)).flatten()

                n_samples = int(X_raw.shape[0])

                cached = {
                    'X_train': X_train,
                    'X_val': X_val,
                    'X_test': X_test,
                    'y_reg_train': y_reg_train,
                    'y_reg_val': y_reg_val,
                    'y_reg_test': y_reg_test,
                    'y_dir_train': y_dir_train,
                    'y_dir_val': y_dir_val,
                    'y_dir_test': y_dir_test,
                    'y_reg_train_scaled': y_reg_train_scaled,
                    'y_reg_val_scaled': y_reg_val_scaled,
                    'target_scaler': target_scaler,
                    'n_samples': n_samples,
                }
                _cache_set(cache_key, cached)

            X_train = cached['X_train']
            X_val = cached['X_val']
            X_test = cached['X_test']
            y_reg_train = cached['y_reg_train']
            y_reg_val = cached['y_reg_val']
            y_reg_test = cached['y_reg_test']
            y_dir_train = cached['y_dir_train']
            y_dir_val = cached['y_dir_val']
            y_dir_test = cached['y_dir_test']
            y_reg_train_scaled = cached['y_reg_train_scaled']
            y_reg_val_scaled = cached['y_reg_val_scaled']
            target_scaler = cached['target_scaler']
            n_samples = cached['n_samples']

            if self.problem_type == 'regression':
                y_train, y_val, y_test = y_reg_train, y_reg_val, y_reg_test
                train_target, val_target = y_reg_train_scaled, y_reg_val_scaled
            else:
                y_train, y_val, y_test = y_dir_train, y_dir_val, y_dir_test
                train_target, val_target = y_train, y_val
            # class balance note
            if self.problem_type == 'classification':
                class_ratio = np.mean(y_train)
                if class_ratio < 0.1 or class_ratio > 0.9:
                    print(f"Severe class imbalance for {company_name} ({class_ratio:.3f}). Consider using class weights.")

            # datasets & loaders
            train_ds = SequenceDataset(X_train, train_target)
            val_ds   = SequenceDataset(X_val,   val_target)
            test_ds  = SequenceDataset(X_test,  y_test)

            train_bs = min(self.batch_size, len(train_ds))
            if train_bs < 2:
                print(f'Insufficient training samples for {company_name} (train size={len(train_ds)}). Skipping...')
                self._record_skip(company_name, "train_batch_too_small", sector)
                return None
            if len(train_ds) % train_bs == 1 and train_bs > 2:
                train_bs -= 1  # avoid batch size 1 for BatchNorm
            val_bs = min(self.batch_size, len(val_ds))
            test_bs = min(self.batch_size, len(test_ds))

            train_loader = DataLoader(train_ds, batch_size=train_bs, shuffle=False,  drop_last=False, num_workers=NUM_WORKERS_TRAIN, persistent_workers=PERSISTENT_WORKERS, pin_memory=PIN_MEMORY)
            val_loader   = DataLoader(val_ds,   batch_size=val_bs,   shuffle=False, drop_last=False, num_workers=NUM_WORKERS_EVAL, persistent_workers=PERSISTENT_WORKERS, pin_memory=PIN_MEMORY)
            test_loader  = DataLoader(test_ds,  batch_size=test_bs,  shuffle=False, drop_last=False, num_workers=NUM_WORKERS_EVAL, persistent_workers=PERSISTENT_WORKERS, pin_memory=PIN_MEMORY)


            # build model
            model = self.build_model((self.sequence_length, len(self.feature_columns)))

            # loss functions
            if self.problem_type == 'regression':
                loss_fn = nn.HuberLoss(delta=self.huber_delta)
            else:
                # use BCEWithLogitsLoss for numerical stability (logits input)
                loss_fn = nn.BCEWithLogitsLoss()

            # optimizer & scheduler
            optimizer = Adam(model.parameters(), lr=self.learning_rate, eps=1e-7, weight_decay=self.weight_decay)
            scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=self.lr_factor, patience=self.lr_patience, min_lr=1e-7)
            early_stopper = EarlyStopper(patience=self.early_stopping_patience, min_delta=self.early_stopping_min_delta, restore_best=True)
            scaler = torch.amp.GradScaler('cuda', enabled=self.mixed_precision)

            # training loop
            max_epochs = self.max_epochs
            best_val = float('inf')
            epochs_trained = 0
            company_loss_rows = []

            for epoch in range(1, max_epochs + 1):
                train_loss = self._train_one_epoch(model, train_loader, optimizer, loss_fn, scaler)
                val_loss = self._eval_one_epoch(model, val_loader, loss_fn)
                scheduler.step(val_loss)
                stop = early_stopper.step(val_loss, model)
                epochs_trained = epoch


                row = {
                    'company': company_name,
                    'sector': sector,
                    'model_type': self.model_type,
                    'problem_type': self.problem_type,
                    'sequence_length': self.sequence_length,
                    'horizon_steps': self.horizon_steps,
                    'epoch': epoch,
                    'train_loss': float(train_loss),
                    'val_loss': float(val_loss),
                    'train_samples': len(X_train),
                    'val_samples': len(X_val),
                    'test_samples': len(X_test),
                }

                company_loss_rows.append(row)
                self.loss_curves.append(row)

                if epoch % 10 == 0 or stop:
                    print(f"  Epoch {epoch:03d} - train {train_loss:.5f} | val {val_loss:.5f}")

                if stop:
                    break

            # restore best model weights (like Keras restore_best_weights=True)
            early_stopper.restore(model)

            # summarize train/val loss for overfitting checks
            best_train_loss = np.nan
            best_val_loss = np.nan
            final_train_loss = np.nan
            final_val_loss = np.nan
            if company_loss_rows:
                best_val_loss = min(r['val_loss'] for r in company_loss_rows)
                best_train_loss = min(r['train_loss'] for r in company_loss_rows)
                final_train_loss = company_loss_rows[-1]['train_loss']
                final_val_loss = company_loss_rows[-1]['val_loss']

            # predictions
            y_pred_raw = self._predict(model, test_loader)  # raw/regression or logits

            if self.problem_type == 'regression':
                y_pred_unscaled = target_scaler.inverse_transform(y_pred_raw.reshape(-1,1)).flatten() if target_scaler is not None else y_pred_raw
                mse = mean_squared_error(y_test, y_pred_unscaled)
                mae = mean_absolute_error(y_test, y_pred_unscaled)
                r2  = r2_score(y_test, y_pred_unscaled)

                # directional metrics (derived)
                y_test_dir = (y_reg_test > 0).astype(int)
                y_pred_dir = (y_pred_unscaled > 0).astype(int)
            else:
                # logits -> probs via sigmoid -> learn best threshold on VAL
                val_logits = self._predict(model, val_loader)
                val_probs = 1.0 / (1.0 + np.exp(-val_logits))
                best_thr, best_thr_score = best_threshold_from_val(y_val, val_probs, metric='mcc')
                val_pred_dir = (val_probs >= best_thr).astype(int)
                val_precision = precision_score(y_val, val_pred_dir, zero_division=0)
                val_recall = recall_score(y_val, val_pred_dir, zero_division=0)
                val_f1 = f1_score(y_val, val_pred_dir, zero_division=0)
                val_mcc = matthews_corrcoef(y_val, val_pred_dir)
                val_directional_accuracy = (y_val == val_pred_dir).mean()
                probs = 1.0 / (1.0 + np.exp(-y_pred_raw))
                y_pred_dir = (probs >= best_thr).astype(int)
                y_test_dir = y_test
                mse = mae = r2 = np.nan

            precision = precision_score(y_test_dir, y_pred_dir, zero_division=0)
            recall    = recall_score(y_test_dir, y_pred_dir, zero_division=0)
            f1        = f1_score(y_test_dir, y_pred_dir, zero_division=0)
            mcc       = matthews_corrcoef(y_test_dir, y_pred_dir)
            directional_accuracy = np.mean(y_test_dir == y_pred_dir)

            result = {
                'company': company_name,
                'sector': sector,
                'model_type': self.model_type,
                'problem_type': self.problem_type,
                'horizon_steps': self.horizon_steps,
                'mse': mse,
                'mae': mae,
                'r2': r2,
                'mcc': mcc,
                'f1': f1,
                'precision': precision,
                'recall': recall,
                'directional_accuracy': directional_accuracy,
                'val_directional_accuracy': val_directional_accuracy if self.problem_type == 'classification' else np.nan,
                'val_mcc': val_mcc if self.problem_type == 'classification' else np.nan,
                'val_f1': val_f1 if self.problem_type == 'classification' else np.nan,
                'val_precision': val_precision if self.problem_type == 'classification' else np.nan,
                'val_recall': val_recall if self.problem_type == 'classification' else np.nan,
                'n_samples': int(n_samples),
                'train_samples': int(X_train.shape[0]),
                'val_samples': int(X_val.shape[0]),
                'test_samples': int(X_test.shape[0]),
                'epochs_trained': epochs_trained
            }
            if self.problem_type == 'classification':
                result['best_threshold'] = best_thr
                result['best_threshold_metric'] = best_thr_score

            if self.problem_type == 'regression':
                print(f"  Regression -> MSE: {mse:.6f}, MAE: {mae:.6f}, R²: {r2:.4f}")
            elif self.problem_type == 'classification':
                print(f"  Classification -> best τ={best_thr:.3f} (val F1={best_thr_score:.4f})")
            print(f"  Directional -> Accuracy: {directional_accuracy:.4f}, MCC: {mcc:.4f}, F1: {f1:.4f}")

            # explicit cleanup (PyTorch handles this, but keeps parity with Enrique2025)
            del model
            self._empty_cache()

            return result

        except Exception as e:
            print(f"Error processing {company_name}: {str(e)}")
            self._record_skip(company_name, f"error:{type(e).__name__}", sector)
            self._empty_cache()
            return None

    def run_pipeline(self):
        company_col = None
        for col_name in ['ticker', 'company', 'symbol']:
            if col_name in self.df.columns:
                company_col = col_name
                break
        if company_col is None:
            company_col = self.df.columns[0]
            print(f"Warning: Using '{company_col}' as company identifier column")

        companies = self.df[company_col].unique()
        print(f"Processing {len(companies)} companies with {self.model_type} model...")
        print(f"Problem type: {self.problem_type}")
        print(f"Sequence length: {self.sequence_length}")
        print(f"Features: {self.feature_columns}")

        successful_companies = 0
        for i, company in enumerate(companies, 1):
            print(f"\n[{i}/{len(companies)}] Processing {company}...")
            company_data = self.df[self.df[company_col] == company].copy()
            sector = company_data['sector'].iloc[0] if 'sector' in company_data.columns else 'Unknown'
            result = self.process_company(company, company_data, sector)
            if result:
                self.results.append(result)
                successful_companies += 1

        print(f"\n{'='*80}")
        print(f"Pipeline completed: {successful_companies}/{len(companies)} companies processed successfully")
        print(f"{'='*80}")
        if self.skip_reasons:
            print("Skip summary:")
            for reason, count in sorted(self.skip_reasons.items(), key=lambda x: (-x[1], x[0])):
                print(f"  {reason}: {count}")
        if self.skipped_companies:
            self.skipped_df = pd.DataFrame(self.skipped_companies)

        if self.results:
            self.results_df = pd.DataFrame(self.results)
            return self.results_df
        else:
            print("No companies were processed successfully!")
            return pd.DataFrame()


    def analyze_results(self):
        if not hasattr(self, 'results_df') or self.results_df.empty:
            print("No results to analyze!")
            return None

        df = self.results_df
        analysis = {}

        print("" + "="*80)
        print("STOCK PREDICTION PIPELINE RESULTS")
        print("="*80)
        print(f"Model: {self.model_type} | Problem: {self.problem_type}")
        print(f"Companies analyzed: {len(df)}")
        print(f"Average samples per company: {df['n_samples'].mean():.0f}")

        print("" + "="*50)
        print("OVERALL PERFORMANCE")
        print("="*50)
        if self.problem_type == 'regression':
            print(f"Mean Squared Error:     {df['mse'].mean():.6f} (±{df['mse'].std():.6f})")
            print(f"Mean Absolute Error:    {df['mae'].mean():.6f} (±{df['mae'].std():.6f})")
            print(f"R² Score:              {df['r2'].mean():.4f} (±{df['r2'].std():.4f})")

        print(f"Directional Accuracy:   {df['directional_accuracy'].mean():.4f} (±{df['directional_accuracy'].std():.4f})")
        print(f"Matthews Correlation:   {df['mcc'].mean():.4f} (±{df['mcc'].std():.4f})")
        print(f"F1 Score:              {df['f1'].mean():.4f} (±{df['f1'].std():.4f})")
        print(f"Precision:             {df['precision'].mean():.4f} (±{df['precision'].std():.4f})")
        print(f"Recall:                {df['recall'].mean():.4f} (±{df['recall'].std():.4f})")

        if 'sector' in df.columns and df['sector'].nunique() > 1:
            print("" + "="*50)
            print("PERFORMANCE BY SECTOR")
            print("="*50)
            sector_stats = df.groupby('sector').agg({
                'directional_accuracy': ['mean', 'std', 'count'],
                'mcc': ['mean', 'std'],
                'r2': 'mean' if self.problem_type == 'regression' else lambda x: np.nan,
                'mae': 'mean' if self.problem_type == 'regression' else lambda x: np.nan
            }).round(4)
            sector_stats.columns = ['_'.join(col).strip() if col[1] else col[0] for col in sector_stats.columns]
            sector_stats = sector_stats.sort_values('directional_accuracy_mean', ascending=False)
            for sector, row in sector_stats.iterrows():
                print(f"{sector:<20} | Acc: {row['directional_accuracy_mean']:.3f}±{row['directional_accuracy_std']:.3f} | "
                      f"MCC: {row['mcc_mean']:.3f} | Companies: {int(row['directional_accuracy_count'])}")

        print("" + "="*50)
        print("TOP 10 PERFORMERS (by Directional Accuracy)")
        print("="*50)
        top_performers = df.nlargest(10, 'directional_accuracy')
        for _, row in top_performers.iterrows():
            print(f"{row['company']:<20} | {row['sector']:<15} | "
                  f"Acc: {row['directional_accuracy']:.3f} | MCC: {row['mcc']:.3f}")

        return analysis

    def save_results(self, results, output_dir=None):
        if results is not None and not results.empty:
            model_name = self.model_type

            if output_dir is None:
                output_dir = f"results/benchmarking/base/{self.horizon_steps}H/"

            if self.problem_type == 'regression':
                out_dir = os.path.join(output_dir, 'regression')
            elif self.problem_type == 'classification':
                out_dir = os.path.join(output_dir, 'classification')

            os.makedirs(out_dir, exist_ok=True)

            output_path = os.path.join(out_dir, f"{model_name}.csv")

            results.to_csv(output_path, index=False)
            print(f"Results saved to {output_path}")
        else:
            print("No results to save.")

    def get_loss_curves_df(self):
        if not self.loss_curves:
            print("No loss curves logged yet.")
            return pd.DataFrame()
        return pd.DataFrame(self.loss_curves)

    def save_loss_curves(self, out_path=None):
        if out_path is None:
            out_path = f"results/benchmarking/base/{self.horizon_steps}H/"
        df = self.get_loss_curves_df()
        if df.empty:
            print("No loss curves to save.")
            return
        if self.problem_type == 'regression':
            out_path = os.path.join(out_path, 'regression', f"{self.model_type}_loss_curves.csv")
        elif self.problem_type == 'classification':
            out_path = os.path.join(out_path, 'classification', f"{self.model_type}_loss_curves.csv")

        os.makedirs(os.path.dirname(out_path), exist_ok=True)

        df.to_csv(out_path, index=False)
        print(f"Loss curves saved to {out_path}")

    def get_feature_importance_analysis(self):
        print("Feature importance analysis not implemented yet.")
        print("Consider implementing SHAP values or permutation importance for better insights.")
        return None

# %% [markdown]
# ## Data Preparation

# %%
master_df = pd.read_parquet(DATA_PATH)

# %%
master_df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'adj_close', 'volume', 'ticker',
#        'ema_12', 'ema_26',
#        ...
#        'cls_acc_20_LSTM', 'cls_brier_20_BiLSTM', 'cls_logloss_20_BiLSTM',
#        'cls_acc_20_BiLSTM', 'cls_brier_20_GRU', 'cls_logloss_20_GRU',
#        'cls_acc_20_GRU', 'cls_brier_20_BiGRU', 'cls_logloss_20_BiGRU',
#        'cls_acc_20_BiGRU'],
#       dtype='object', length=118)

# %%
master_df
# Out:
#              date       open       high        low      close  adj_close  \
# 0      2012-09-04  95.108574  96.448570  94.928574  96.424286  87.121140
# 1      2012-09-05  96.510002  96.621429  95.657143  95.747147  86.509338
# 2      2012-09-06  96.167145  96.898575  95.828575  96.610001  87.288956
# 3      2012-09-07  96.864288  97.497147  96.538574  97.205711  87.827171
# 4      2012-09-10  97.207146  97.612854  94.585716  94.677139  85.542564
# ...           ...        ...        ...        ...        ...        ...
# 108587 2017-08-28  76.900002  76.940002  76.260002  76.470001  76.470001
# 108588 2017-08-29  76.209999  76.489998  76.080002  76.449997  76.449997
# 108589 2017-08-30  76.239998  76.449997  76.059998  76.099998  76.099998
# 108590 2017-08-31  76.269997  76.489998  76.050003  76.330002  76.330002
# 108591 2017-09-01  76.370003  76.849998  76.320000  76.570000  76.570000
#
#              volume ticker     ema_12     ema_26  ...  cls_acc_20_LSTM  \
# 0        91973000.0   AAPL        NaN        NaN  ...              NaN
# 1        84093800.0   AAPL        NaN        NaN  ...              NaN
# 2        97799100.0   AAPL        NaN        NaN  ...              NaN
# 3        82416600.0   AAPL        NaN        NaN  ...              NaN
# 4       121999500.0   AAPL        NaN        NaN  ...              NaN
# ...             ...    ...        ...        ...  ...              ...
# 108587    8229700.0    XOM  77.187452  78.267858  ...             0.50
# 108588    7060400.0    XOM  77.073998  78.133202  ...             0.50
# 108589    8218000.0    XOM  76.924151  77.982594  ...             0.50
# 108590   15641700.0    XOM  76.832744  77.860180  ...             0.50
# 108591    7340800.0    XOM  76.792322  77.764611  ...             0.45
#
#         cls_brier_20_BiLSTM  cls_logloss_20_BiLSTM  cls_acc_20_BiLSTM  \
# 0                       NaN                    NaN                NaN
# 1                       NaN                    NaN                NaN
# 2                       NaN                    NaN                NaN
# 3                       NaN                    NaN                NaN
# 4                       NaN                    NaN                NaN
# ...                     ...                    ...                ...
# 108587             0.296700               0.790579               0.35
# 108588             0.306727               0.810965               0.30
# 108589             0.315684               0.829134               0.25
# 108590             0.308160               0.813921               0.30
# 108591             0.301695               0.800904               0.35
#
#         cls_brier_20_GRU  cls_logloss_20_GRU  cls_acc_20_GRU  \
# 0                    NaN                 NaN             NaN
# 1                    NaN                 NaN             NaN
# 2                    NaN                 NaN             NaN
# 3                    NaN                 NaN             NaN
# 4                    NaN                 NaN             NaN
# ...                  ...                 ...             ...
# 108587          0.267328            0.728414            0.45
# 108588          0.270884            0.735631            0.45
# 108589          0.274612            0.743175            0.45
# 108590          0.271915            0.737699            0.45
# 108591          0.271375            0.736616            0.45
#
#         cls_brier_20_BiGRU  cls_logloss_20_BiGRU  cls_acc_20_BiGRU
# 0                      NaN                   NaN               NaN
# 1                      NaN                   NaN               NaN
# 2                      NaN                   NaN               NaN
# 3                      NaN                   NaN               NaN
# 4                      NaN                   NaN               NaN
# ...                    ...                   ...               ...
# 108587            0.243744              0.680346               0.6
# 108588            0.245078              0.683081               0.6
# 108589            0.245080              0.683084               0.6
# 108590            0.243949              0.680646               0.6
# 108591            0.244346              0.681466               0.6
#
# [108592 rows x 118 columns]

# %%
columns_to_check = [

    # Sentiment (single)
    'sentiment',

    # Emotions
    'emotion_anger', 'emotion_disgust', 'emotion_fear', 'emotion_joy',
    'emotion_neutral', 'emotion_sadness', 'emotion_surprize',
    'emotion_anger_pct', 'emotion_disgust_pct', 'emotion_fear_pct',
    'emotion_joy_pct', 'emotion_neutral_pct', 'emotion_sadness_pct',
    'emotion_surprize_pct',

    # Unified emotion
    'positive_emotion', 'negative_emotion', 'uncertainty_emotion',
    'positive_emotion_pct', 'negative_emotion_pct', 'uncertainty_emotion_pct',

    # Stance
    'stance_label', 'stance_score',

    # FinBERT
    'finbert_label', 'finbert_score', 'finbert_up', 'finbert_down',
    'finbert_neutral',

    # Sector aggregates
    'sector_open_mean', 'sector_high_mean', 'sector_low_mean', 'sector_close_mean',
    'sector_volume_mean', 'sector_ret_1d', 'sector_ret_5d',
    'sector_ret_20d', 'sector_range', 'sector_vol_20d',
    'ema_12_sector', 'ema_26_sector', 'ema_50_sector', 'macd_12_26_9_sector',
    'macdh_12_26_9_sector', 'macds_12_26_9_sector', 'rsi_14_sector',
    'sector_bb_upper', 'sector_bb_middle', 'sector_bb_lower',
    'market_close', 'sector_rel_strength', 'sector_dispersion_1d',

    # Meta regression predictions
    'reg_pred_ret_1d_LSTM', 'reg_pred_ret_1d_BiLSTM', 'reg_pred_ret_1d_GRU',
    'reg_pred_ret_1d_BiGRU',

    # Regression errors/diagnostics
    'reg_abs_err_lag1_LSTM', 'reg_mae_20_LSTM',
    'reg_rmse_20_LSTM', 'reg_dir_acc_20_LSTM',

    'reg_abs_err_lag1_BiLSTM',
    'reg_mae_20_BiLSTM', 'reg_rmse_20_BiLSTM', 'reg_dir_acc_20_BiLSTM',

    'reg_abs_err_lag1_GRU',
    'reg_mae_20_GRU', 'reg_rmse_20_GRU', 'reg_dir_acc_20_GRU',

    'reg_abs_err_lag1_BiGRU',
    'reg_mae_20_BiGRU', 'reg_rmse_20_BiGRU', 'reg_dir_acc_20_BiGRU',

    # Meta classification predictions
    'cls_prob_up_1d_LSTM', 'cls_prob_up_1d_BiLSTM', 'cls_prob_up_1d_GRU',
    'cls_prob_up_1d_BiGRU',

    # Classification diagnostics
    'cls_brier_20_LSTM', 'cls_logloss_20_LSTM', 'cls_acc_20_LSTM',

    'cls_brier_20_BiLSTM', 'cls_logloss_20_BiLSTM', 'cls_acc_20_BiLSTM',

    'cls_brier_20_GRU', 'cls_logloss_20_GRU', 'cls_acc_20_GRU',

    'cls_brier_20_BiGRU', 'cls_logloss_20_BiGRU', 'cls_acc_20_BiGRU',
]

print(f"Initial master_df shape: {master_df.shape}")

master_df = master_df.dropna(subset=columns_to_check)

print(f"After dropping NaNs in selected columns, master_df shape: {master_df.shape}")

master_df.reset_index(drop=True, inplace=True)

print(master_df)
# Out:
# Initial master_df shape: (108592, 118)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 68
#      64 print(f"Initial master_df shape: {master_df.shape}")
#      66 master_df = master_df.dropna(subset=columns_to_check, inplace=True)
# ---> 68 print(f"After dropping NaNs in selected columns, master_df shape: {master_df.shape}")
#      70 master_df.reset_index(drop=True, inplace=True)
#      72 print(master_df)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
print(master_df.columns)
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'adj_close', 'volume', 'ticker',
#        'ema_12', 'ema_26',
#        ...
#        'cls_acc_20_LSTM', 'cls_brier_20_BiLSTM', 'cls_logloss_20_BiLSTM',
#        'cls_acc_20_BiLSTM', 'cls_brier_20_GRU', 'cls_logloss_20_GRU',
#        'cls_acc_20_GRU', 'cls_brier_20_BiGRU', 'cls_logloss_20_BiGRU',
#        'cls_acc_20_BiGRU'],
#       dtype='object', length=118)

# %%
feature_columns = [
    'open', 'high', 'low', 'close', 'volume',
    'roll_ret_1d', 'roll_ret_5d', 
    'roll_ret_20d',
    
    'ema_12', 'ema_26', 'ema_50', 'macd_12_26_9', 'macdh_12_26_9',
    'macds_12_26_9', 'rsi_14', 'stochrsik_14_14_3_3', 'stochrsid_14_14_3_3',
    'atrr_14', 'bb_upper', 'bb_middle', 'bb_lower', 'obv',
]

# feature_columns.extend(new_indicator_columns)

all_pipelines = {}
all_results_dfs = {}
all_analyses = {}

# %%
print(master_df.shape)
master_df = master_df.dropna(subset=feature_columns).sort_values(['ticker','date'])
print(master_df.shape)
# Out:
# (81700, 118)
# (81700, 118)

# %% [markdown]
# ## Pipeline Execution

# %%
sentiment_columns = [
    'sentiment',
]

emotion_columns = [
    'emotion_anger', 'emotion_disgust', 'emotion_fear', 'emotion_joy',
    'emotion_neutral', 'emotion_sadness', 'emotion_surprize',
    'emotion_anger_pct', 'emotion_disgust_pct', 'emotion_fear_pct',
    'emotion_joy_pct', 'emotion_neutral_pct', 'emotion_sadness_pct',
    'emotion_surprize_pct',
]

unified_emotion_columns = [
    'positive_emotion', 'negative_emotion','uncertainty_emotion',
    'positive_emotion_pct', 'negative_emotion_pct','uncertainty_emotion_pct',
]

stance_columns = [
    'stance_label', 'stance_score',
]

finbert_columns = [
    'finbert_label', 'finbert_score', 'finbert_up', 'finbert_down',
    'finbert_neutral',
]

sector_columns = ['sector_open_mean', 'sector_high_mean', 'sector_low_mean', 'sector_close_mean',
                  'sector_volume_mean', 'sector_ret_1d', 'sector_ret_5d',
                  'sector_ret_20d', 'sector_range', 'sector_vol_20d', 
                  
                  'ema_12_sector','ema_26_sector', 'ema_50_sector', 'macd_12_26_9_sector',
                  'macdh_12_26_9_sector', 'macds_12_26_9_sector', 'rsi_14_sector',
                  'sector_bb_upper', 'sector_bb_middle', 'sector_bb_lower',
                  'market_close', 'sector_rel_strength', 'sector_dispersion_1d']

meta_regression_columns = [
    'reg_pred_ret_1d_LSTM', 'reg_pred_ret_1d_BiLSTM', 'reg_pred_ret_1d_GRU',
    'reg_pred_ret_1d_BiGRU',
]

meta_classification_columns = [
    'cls_prob_up_1d_LSTM', 'cls_prob_up_1d_BiLSTM', 'cls_prob_up_1d_GRU',
    'cls_prob_up_1d_BiGRU',
]

meta_regression_err_columns = [
    'reg_abs_err_lag1_LSTM', 'reg_mae_20_LSTM',
    'reg_rmse_20_LSTM', 'reg_dir_acc_20_LSTM',

    'reg_abs_err_lag1_BiLSTM',
    'reg_mae_20_BiLSTM', 'reg_rmse_20_BiLSTM', 'reg_dir_acc_20_BiLSTM',

    'reg_abs_err_lag1_GRU',
    'reg_mae_20_GRU', 'reg_rmse_20_GRU', 'reg_dir_acc_20_GRU',

    'reg_abs_err_lag1_BiGRU',
    'reg_mae_20_BiGRU', 'reg_rmse_20_BiGRU', 'reg_dir_acc_20_BiGRU',]

meta_classification_err_columns = [
    'cls_brier_20_LSTM', 'cls_logloss_20_LSTM', 'cls_acc_20_LSTM',

    'cls_brier_20_BiLSTM', 'cls_logloss_20_BiLSTM', 'cls_acc_20_BiLSTM',

    'cls_brier_20_GRU', 'cls_logloss_20_GRU', 'cls_acc_20_GRU',

    'cls_brier_20_BiGRU', 'cls_logloss_20_BiGRU', 'cls_acc_20_BiGRU',
]

# %%
# Feature sets
feature_sets = {
    # 'base': feature_columns,
    # 'sentiment': feature_columns + sentiment_columns,,
    # 'emotion': feature_columns + emotion_columns,
    # 'unified_emotion': feature_columns + unified_emotion_columns,
    # 'finbert': feature_columns + finbert_columns,
    # 'all_nlp': feature_columns + sentiment_columns + emotion_columns + unified_emotion_columns + stance_columns + finbert_columns,
    # 'sector': feature_columns + sector_columns,
    # 'sector_sentiment': feature_columns + sector_columns + sentiment_columns,
    # 'sector_emotion': feature_columns + sector_columns + emotion_columns,
    # 'sector_unified_emotion': feature_columns + sector_columns + unified_emotion_columns,
    # 'sector_finbert': feature_columns + sector_columns + finbert_columns,
    # 'sector_all_nlp': feature_columns + sector_columns + sentiment_columns + emotion_columns + unified_emotion_columns + stance_columns + finbert_columns,
    
    'meta': feature_columns + meta_regression_columns + meta_classification_columns,
    
    'meta_err': feature_columns + meta_regression_columns + meta_classification_columns + meta_regression_err_columns + meta_classification_err_columns,
    
    'meta_sentiment': feature_columns + meta_regression_columns + meta_classification_columns + sentiment_columns,
    'meta_stance': feature_columns + meta_regression_columns + meta_classification_columns + stance_columns,
    'meta_emotion': feature_columns + meta_regression_columns + meta_classification_columns + emotion_columns,
    'meta_unified_emotion': feature_columns + meta_regression_columns + meta_classification_columns + unified_emotion_columns,
    'meta_finbert': feature_columns + meta_regression_columns + meta_classification_columns + finbert_columns,
    'meta_all_nlp': feature_columns + meta_regression_columns + meta_classification_columns + sentiment_columns + emotion_columns + unified_emotion_columns + stance_columns + finbert_columns,
    'meta_sector': feature_columns + meta_regression_columns + meta_classification_columns + sector_columns,
    'meta_sector_sentiment': feature_columns + meta_regression_columns + meta_classification_columns + sector_columns + sentiment_columns,
    'meta_sector_stance': feature_columns + meta_regression_columns + meta_classification_columns + sector_columns + stance_columns,
    'meta_sector_emotion': feature_columns + meta_regression_columns + meta_classification_columns + sector_columns + emotion_columns,
    'meta_sector_unified_emotion': feature_columns + meta_regression_columns + meta_classification_columns + sector_columns + unified_emotion_columns,
    'meta_sector_finbert': feature_columns + meta_regression_columns + meta_classification_columns + sector_columns + finbert_columns,
    'meta_sector_all_nlp': feature_columns + meta_regression_columns + meta_classification_columns + sector_columns + sentiment_columns + emotion_columns + unified_emotion_columns + stance_columns + finbert_columns,
    
    'meta_err_sentiment': feature_columns + meta_regression_columns + meta_classification_columns + meta_regression_err_columns + meta_classification_err_columns + sentiment_columns,
    'meta_err_stance': feature_columns + meta_regression_columns + meta_classification_columns + meta_regression_err_columns + meta_classification_err_columns + stance_columns,
    'meta_err_emotion': feature_columns + meta_regression_columns + meta_classification_columns + meta_regression_err_columns + meta_classification_err_columns + emotion_columns,
    'meta_err_unified_emotion': feature_columns + meta_regression_columns + meta_classification_columns + meta_regression_err_columns + meta_classification_err_columns + unified_emotion_columns,
    'meta_err_finbert': feature_columns + meta_regression_columns + meta_classification_columns + meta_regression_err_columns + meta_classification_err_columns + finbert_columns,
    'meta_err_all_nlp': feature_columns + meta_regression_columns + meta_classification_columns + meta_regression_err_columns + meta_classification_err_columns + sentiment_columns + emotion_columns + unified_emotion_columns + stance_columns + finbert_columns, 
    'meta_err_sector': feature_columns + meta_regression_columns + meta_classification_columns + meta_regression_err_columns + meta_classification_err_columns + sector_columns,
    'meta_err_sector_sentiment': feature_columns + meta_regression_columns + meta_classification_columns + meta_regression_err_columns + meta_classification_err_columns + sector_columns + sentiment_columns,
    'meta_err_sector_stance': feature_columns + meta_regression_columns + meta_classification_columns + meta_regression_err_columns + meta_classification_err_columns + sector_columns + stance_columns,
    'meta_err_sector_emotion': feature_columns + meta_regression_columns + meta_classification_columns + meta_regression_err_columns + meta_classification_err_columns + sector_columns + emotion_columns,
    'meta_err_sector_unified_emotion': feature_columns + meta_regression_columns + meta_classification_columns + meta_regression_err_columns + meta_classification_err_columns + sector_columns + unified_emotion_columns,
    'meta_err_sector_finbert': feature_columns + meta_regression_columns + meta_classification_columns + meta_regression_err_columns + meta_classification_err_columns + sector_columns + finbert_columns,
    'meta_err_sector_all_nlp': feature_columns + meta_regression_columns + meta_classification_columns + meta_regression_err_columns + meta_classification_err_columns + sector_columns + sentiment_columns + emotion_columns + unified_emotion_columns + stance_columns + finbert_columns,    
    
}

# Grouping of feature sets to tune
feature_groups = {
    'base': ['meta', 'meta_err'],
    'nlp': ['meta_sentiment', 'meta_stance', 'meta_emotion', 'meta_unified_emotion', 'meta_finbert', 'meta_all_nlp', 'meta_err_sentiment', 'meta_err_stance', 'meta_err_emotion', 'meta_err_unified_emotion', 'meta_err_finbert', 'meta_err_all_nlp'],
    'sector': ['meta_sector', 'meta_sector_sentiment', 'meta_sector_stance', 'meta_sector_emotion', 'meta_sector_unified_emotion', 'meta_sector_finbert', 'meta_sector_all_nlp', 'meta_err_sector', 'meta_err_sector_sentiment', 'meta_err_sector_stance', 'meta_err_sector_emotion', 'meta_err_sector_unified_emotion', 'meta_err_sector_finbert', 'meta_err_sector_all_nlp'],

}

# %%
# Run top-ranked hyperparameter settings per model type from all Optuna CSVs in classification folder
from pathlib import Path
import pandas as pd

PROBLEM_TYPE = "regression"  # or "classification"
CSV_DIR = RESULTS_ROOT / PROBLEM_TYPE
optuna_csvs = sorted(CSV_DIR.glob("optuna_tuning_*.csv"))

if not optuna_csvs:
    raise FileNotFoundError(f"No optuna_tuning_*.csv found in {CSV_DIR}")

# Map possible spelling mismatch
feature_key_alias = {
    "sentinment": "sentiment",  # handle typo variants
}

model_types = ["LSTM", "BiLSTM", "GRU", "BiGRU"]

all_pipelines = {}
all_results_dfs = {}
all_analyses = {}

for OPTUNA_CSV in optuna_csvs:
    print(f"{'='*25} USING OPTUNA CSV: {OPTUNA_CSV.name} {'='*25}")

    # Derive output directory from optuna CSV name
    # Example: optuna_tuning_base_1H.csv -> base
    name_parts = OPTUNA_CSV.stem.split('_')
    feature_group = name_parts[2] if len(name_parts) >= 3 else 'unknown'

    RESULTS_OUT_DIR = CSV_DIR / feature_group
    RESULTS_OUT_DIR.mkdir(parents=True, exist_ok=True)

    optuna_df = pd.read_csv(OPTUNA_CSV)

    # Optional: ensure we respect the CSV ordering (first occurrence = best, if CSV is sorted)
    # If you want to enforce sorting by value, uncomment:
    # optuna_df = optuna_df.sort_values("value", ascending=False)

    for model_type in model_types:
        rows = optuna_df[optuna_df["params_model_type"] == model_type]
        if rows.empty:
            print(f"[SKIP] No rows for model_type={model_type} in {OPTUNA_CSV.name}")
            continue

        row = rows.iloc[0]

        feature_key = row["params_feature_set"]
        if feature_key in feature_key_alias:
            feature_key = feature_key_alias[feature_key]

        if feature_key not in feature_sets:
            print(f"[SKIP] Feature set '{row['params_feature_set']}' not found in feature_sets")
            continue

        horizon_steps = int(row["params_horizon_steps"])
        horizon_tag = f"{horizon_steps}H"

        print(f"{'='*25} RUNNING TOP {model_type} ({feature_key}) | {horizon_tag} {'='*25}")

        pipeline = StockPredictionPipeline(
            df=master_df,
            feature_columns=feature_sets[feature_key],
            model_type=row["params_model_type"],
            sequence_length=int(row["params_sequence_length"]),
            problem_type=PROBLEM_TYPE,
            horizon_steps=horizon_steps,
            batch_size=int(row["params_batch_size"]),
            learning_rate=float(row["params_learning_rate"]),
            dropout=float(row["params_dropout"]),
            inter_rnn_drop=float(row["params_inter_rnn_drop"]),
            lr_factor=float(row["params_lr_factor"]),
            lr_patience=int(row["params_lr_patience"]),
            early_stopping_min_delta=float(row["params_early_stopping_min_delta"]),
            early_stopping_patience=int(row["params_early_stopping_patience"]),
            num_layers=int(row["params_num_layers"]),
            max_epochs=int(row["params_max_epochs"]),
            hidden1=int(row["params_hidden1"]),
            hidden2=int(row["params_hidden2"]),
            huber_delta=float(row["params_huber_delta"]),
            weight_decay=float(row["params_weight_decay"]),
        )

        results_df = pipeline.run_pipeline()

        # Save selected params snapshot (per model, include horizon)
        row.to_frame().T.to_csv(RESULTS_OUT_DIR / f"{model_type}_{horizon_tag}_params.csv", index=False)

        # Save loss curves with horizon tag
        loss_df = pipeline.get_loss_curves_df()
        if not loss_df.empty:
            loss_df.to_csv(RESULTS_OUT_DIR / f"{model_type}_{horizon_tag}_loss_curves.csv", index=False)

        if results_df is not None and not results_df.empty:
            analysis = pipeline.analyze_results()
            # Save per-model results with unique name
            results_df.to_csv(RESULTS_OUT_DIR / f"{model_type}_{horizon_tag}_results.csv", index=False)
            all_pipelines[(OPTUNA_CSV.name, model_type)] = pipeline
            all_results_dfs[(OPTUNA_CSV.name, model_type)] = results_df
            all_analyses[(OPTUNA_CSV.name, model_type)] = analysis
            print(f"Saved results for {model_type} to {RESULTS_OUT_DIR}")
        else:
            print(f"[FAILED] Pipeline for {model_type} did not produce any results.")

        del pipeline
# Out:
# ========================= USING OPTUNA CSV: optuna_tuning_base_1H.csv =========================
# ========================= RUNNING TOP GRU (meta) | 1H =========================
# Pipeline initialized for a 'classification' problem with horizon 1 steps. Device: cuda
# Processing 87 companies with GRU model...
# Problem type: classification
# Sequence length: 15
# Features: ['open', 'high', 'low', 'close', 'volume', 'roll_ret_1d', 'roll_ret_5d', 'roll_ret_20d', 'ema_12', 'ema_26', 'ema_50', 'macd_12_26_9', 'macdh_12_26_9', 'macds_12_26_9', 'rsi_14', 'stochrsik_14_14_3_3', 'stochrsid_14_14_3_3', 'atrr_14', 'bb_upper', 'bb_middle', 'bb_lower', 'obv', 'reg_pred_ret_1d_LSTM', 'reg_pred_ret_1d_BiLSTM', 'reg_pred_ret_1d_GRU', 'reg_pred_ret_1d_BiGRU', 'cls_prob_up_1d_LSTM', 'cls_prob_up_1d_BiLSTM', 'cls_prob_up_1d_GRU', 'cls_prob_up_1d_BiGRU']
#
# [1/87] Processing AAPL...
#
# Processing AAPL (Consumer Goods)...
#   Epoch 010 - train 0.66839 | val 0.91760
#   Epoch 016 - train 0.64177 | val 0.99010
#   Classification -> best τ=0.500 (val F1=0.2425)
#   Directional -> Accuracy: 0.5312, MCC: 0.0000, F1: 0.3182
#
# [2/87] Processing ABB...
#
# Processing ABB (Industrial Goods)...
#   Epoch 010 - train 0.64655 | val 1.43956
#   Epoch 020 - train 0.61873 | val 2.12440
#   Classification -> best τ=0.535 (val F1=0.2841)
#   Directional -> Accuracy: 0.5469, MCC: 0.2348, F1: 0.3830
#
# [3/87] Processing ABBV...
#
# Processing ABBV (Healthcare)...
#   Epoch 010 - train 0.64429 | val 0.68562
#   Epoch 020 - train 0.61658 | val 0.76380
#   Classification -> best τ=0.650 (val F1=0.3637)
#   Directional -> Accuracy: 0.6719, MCC: 0.3586, F1: 0.6557
#
# [4/87] Processing AEP...
#
# Processing AEP (Utilities)...
#   Epoch 010 - train 0.65240 | val 0.74132
#   Epoch 017 - train 0.63502 | val 0.75920
#   Classification -> best τ=0.455 (val F1=0.2460)
#   Directional -> Accuracy: 0.5781, MCC: -0.1042, F1: 0.7327
#
# [5/87] Processing AGFS...
#
# Processing AGFS (Conglomerates)...
# No training data in range for AGFS. Skipping...
#
# [6/87] Processing AMGN...
#
# Processing AMGN (Healthcare)...
#   Epoch 010 - train 0.66223 | val 0.67222
#   Epoch 020 - train 0.58975 | val 0.68407
#   Classification -> best τ=0.465 (val F1=0.4686)
#   Directional -> Accuracy: 0.4688, MCC: 0.0976, F1: 0.1500
#
# [7/87] Processing AMZN...
#
# Processing AMZN (Services)...
#   Epoch 010 - train 0.64805 | val 0.93395
#   Epoch 018 - train 0.60844 | val 0.84150
#   Classification -> best τ=0.555 (val F1=0.3303)
#   Directional -> Accuracy: 0.4844, MCC: 0.0774, F1: 0.1951
#
# [8/87] Processing BA...
#
# Processing BA (Industrial Goods)...
#   Epoch 010 - train 0.64678 | val 0.67682
#   Epoch 020 - train 0.60393 | val 0.68860
#   Classification -> best τ=0.440 (val F1=0.3631)
#   Directional -> Accuracy: 0.6250, MCC: 0.3554, F1: 0.5200
#
# [9/87] Processing BABA...
#
# Processing BABA (Services)...
# No training data in range for BABA. Skipping...
#
# [10/87] Processing BAC...
#
# Processing BAC (Financial)...
#   Epoch 010 - train 0.64989 | val 0.88998
#   Epoch 016 - train 0.60658 | val 1.00255
#   Classification -> best τ=0.595 (val F1=0.1803)
#   Directional -> Accuracy: 0.5781, MCC: 0.0000, F1: 0.0000
#
# [11/87] Processing BBL...
#
# Processing BBL (Basic Matierials)...
#   Epoch 010 - train 0.63671 | val 0.68219
#   Epoch 020 - train 0.61946 | val 0.70391
#   Classification -> best τ=0.660 (val F1=0.2197)
#   Directional -> Accuracy: 0.4844, MCC: -0.0180, F1: 0.4407
#
# [12/87] Processing BCH...
#
# Processing BCH (Financial)...
#   Epoch 010 - train 0.65191 | val 0.74822
#   Epoch 020 - train 0.63451 | val 0.90038
#   Classification -> best τ=0.400 (val F1=0.3570)
#   Directional -> Accuracy: 0.4219, MCC: 0.0000, F1: 0.5934
#
# [13/87] Processing BHP...
#
# Processing BHP (Basic Matierials)...
#   Epoch 010 - train 0.66415 | val 0.69748
#   Epoch 020 - train 0.61773 | val 0.67429
#   Classification -> best τ=0.550 (val F1=0.4216)
#   Directional -> Accuracy: 0.4062, MCC: -0.1412, F1: 0.5250
#
# [14/87] Processing BP...
#
# Processing BP (Basic Matierials)...
#   Epoch 010 - train 0.67381 | val 0.89068
#   Epoch 016 - train 0.62244 | val 0.93850
#   Classification -> best τ=0.415 (val F1=0.2521)
#   Directional -> Accuracy: 0.5312, MCC: 0.0636, F1: 0.4828
#
# [15/87] Processing BRK-A...
#
# Processing BRK-A (Financial)...
#   Epoch 010 - train 0.66116 | val 0.91141
#   Epoch 016 - train 0.62933 | val 1.14192
#   Classification -> best τ=0.415 (val F1=0.3920)
#   Directional -> Accuracy: 0.4375, MCC: 0.0000, F1: 0.6087
#
# [16/87] Processing BSAC...
#
# Processing BSAC (Financial)...
#   Epoch 010 - train 0.66574 | val 1.05328
#   Epoch 017 - train 0.60972 | val 1.20370
#   Classification -> best τ=0.515 (val F1=0.0877)
#   Directional -> Accuracy: 0.6250, MCC: 0.2928, F1: 0.2500
#
# [17/87] Processing BUD...
#
# Processing BUD (Consumer Goods)...
#   Epoch 010 - train 0.66908 | val 0.74647
#   Epoch 016 - train 0.62946 | val 0.82092
#   Classification -> best τ=0.600 (val F1=0.2438)
#   Directional -> Accuracy: 0.5312, MCC: 0.1291, F1: 0.1667
#
# [18/87] Processing C...
#
# Processing C (Financial)...
#   Epoch 010 - train 0.64455 | val 0.75010
#   Epoch 016 - train 0.59327 | val 0.75155
#   Classification -> best τ=0.580 (val F1=0.2345)
#   Directional -> Accuracy: 0.5625, MCC: -0.1486, F1: 0.0000
#
# [19/87] Processing CAT...
#
# Processing CAT (Industrial Goods)...
#   Epoch 010 - train 0.66206 | val 0.83380
#   Epoch 016 - train 0.64366 | val 0.99141
#   Classification -> best τ=0.560 (val F1=0.2697)
#   Directional -> Accuracy: 0.5312, MCC: 0.1291, F1: 0.1667
#
# [20/87] Processing CELG...
#
# Processing CELG (Healthcare)...
#   Epoch 010 - train 0.65698 | val 0.67494
#   Epoch 017 - train 0.63007 | val 0.68856
#   Classification -> best τ=0.495 (val F1=0.3969)
#   Directional -> Accuracy: 0.5625, MCC: 0.1352, F1: 0.5172
#
# [21/87] Processing CHL...
#
# Processing CHL (Technology)...
#   Epoch 010 - train 0.63827 | val 0.73480
#   Epoch 017 - train 0.62165 | val 0.73349
#   Classification -> best τ=0.445 (val F1=0.2781)
#   Directional -> Accuracy: 0.5469, MCC: 0.1588, F1: 0.6588
#
# [22/87] Processing CHTR...
#
# Processing CHTR (Services)...
#   Epoch 010 - train 0.67627 | val 0.68702
#   Epoch 020 - train 0.65211 | val 0.70448
#   Classification -> best τ=0.375 (val F1=0.2810)
#   Directional -> Accuracy: 0.5000, MCC: 0.0000, F1: 0.2727
#
# [23/87] Processing CMCSA...
#
# Processing CMCSA (Services)...
#   Epoch 010 - train 0.64196 | val 0.65168
#   Epoch 020 - train 0.57407 | val 1.08236
#   Classification -> best τ=0.505 (val F1=0.4492)
#   Directional -> Accuracy: 0.5625, MCC: 0.1912, F1: 0.1250
#
# [24/87] Processing CODI...
#
# Processing CODI (Conglomerates)...
#   Epoch 010 - train 0.65382 | val 0.82577
#   Epoch 016 - train 0.60575 | val 1.00962
#   Classification -> best τ=0.545 (val F1=0.0214)
#   Directional -> Accuracy: 0.6406, MCC: 0.2776, F1: 0.4651
#
# [25/87] Processing CSCO...
#
# Processing CSCO (Technology)...
#   Epoch 010 - train 0.64812 | val 0.64213
#   Epoch 020 - train 0.60627 | val 0.69969
#   Classification -> best τ=0.515 (val F1=0.3362)
#   Directional -> Accuracy: 0.5781, MCC: 0.1601, F1: 0.5263
#
# [26/87] Processing CVX...
#
# Processing CVX (Basic Matierials)...
#   Epoch 010 - train 0.65972 | val 0.84703
#   Epoch 016 - train 0.62962 | val 0.87416
#   Classification -> best τ=0.480 (val F1=0.2774)
#   Directional -> Accuracy: 0.5312, MCC: 0.0000, F1: 0.0000
#
# [27/87] Processing D...
#
# Processing D (Utilities)...
#   Epoch 010 - train 0.62730 | val 0.81081
#   Epoch 018 - train 0.55822 | val 0.93427
#   Classification -> best τ=0.480 (val F1=0.3721)
#   Directional -> Accuracy: 0.5469, MCC: 0.0998, F1: 0.6133
#
# [28/87] Processing DHR...
#
# Processing DHR (Industrial Goods)...
#   Epoch 010 - train 0.68329 | val 0.73971
#   Epoch 017 - train 0.63221 | val 0.88304
#   Classification -> best τ=0.485 (val F1=0.2345)
#   Directional -> Accuracy: 0.4844, MCC: 0.0000, F1: 0.0000
#
# [29/87] Processing DIS...
#
# Processing DIS (Services)...
#   Epoch 010 - train 0.65622 | val 1.36670
#   Epoch 016 - train 0.62521 | val 1.55857
#   Classification -> best τ=0.570 (val F1=0.3411)
#   Directional -> Accuracy: 0.4531, MCC: 0.0000, F1: 0.0000
#
# [30/87] Processing DUK...
#
# Processing DUK (Utilities)...
#   Epoch 010 - train 0.67079 | val 0.76142
#   Epoch 020 - train 0.60493 | val 0.87331
#   Classification -> best τ=0.545 (val F1=0.4079)
#   Directional -> Accuracy: 0.5625, MCC: 0.1420, F1: 0.5758
#
# [31/87] Processing EXC...
#
# Processing EXC (Utilities)...
#   Epoch 010 - train 0.66624 | val 1.00103
#   Epoch 016 - train 0.62796 | val 1.47431
#   Classification -> best τ=0.480 (val F1=0.3093)
#   Directional -> Accuracy: 0.5000, MCC: 0.0000, F1: 0.6667
#
# [32/87] Processing FB...
#
# Processing FB (Technology)...
#   Epoch 010 - train 0.64480 | val 1.01939
#   Epoch 016 - train 0.62761 | val 1.51527
#   Classification -> best τ=0.495 (val F1=0.3430)
#   Directional -> Accuracy: 0.4688, MCC: -0.1013, F1: 0.5641
#
# [33/87] Processing GD...
#
# Processing GD (Industrial Goods)...
#   Epoch 010 - train 0.65438 | val 0.71233
#   Epoch 016 - train 0.62865 | val 0.84528
#   Classification -> best τ=0.455 (val F1=0.2033)
#   Directional -> Accuracy: 0.4375, MCC: 0.0000, F1: 0.6087
#
# [34/87] Processing GE...
#
# Processing GE (Industrial Goods)...
#   Epoch 010 - train 0.62825 | val 0.91660
#   Epoch 017 - train 0.56492 | val 1.11780
#   Classification -> best τ=0.515 (val F1=0.2708)
#   Directional -> Accuracy: 0.4844, MCC: 0.2206, F1: 0.1951
#
# [35/87] Processing GOOG...
#
# Processing GOOG (Technology)...
#   Epoch 010 - train 0.62404 | val 0.72900
#   Epoch 020 - train 0.58279 | val 0.72397
#   Classification -> best τ=0.500 (val F1=0.2721)
#   Directional -> Accuracy: 0.4688, MCC: 0.0000, F1: 0.0000
#
# [36/87] Processing HD...
#
# Processing HD (Services)...
#   Epoch 010 - train 0.64217 | val 0.74709
#   Epoch 018 - train 0.60642 | val 0.70091
#   Classification -> best τ=0.430 (val F1=0.2582)
#   Directional -> Accuracy: 0.5625, MCC: -0.0129, F1: 0.7083
#
# [37/87] Processing HON...
#
# Processing HON (Industrial Goods)...
#   Epoch 010 - train 0.62061 | val 0.88891
#   Epoch 016 - train 0.60183 | val 1.20873
#   Classification -> best τ=0.640 (val F1=0.3052)
#   Directional -> Accuracy: 0.5156, MCC: 0.0739, F1: 0.1143
#
# [38/87] Processing HRG...
#
# Processing HRG (Conglomerates)...
#   Epoch 010 - train 0.66028 | val 0.72340
#   Epoch 016 - train 0.63314 | val 0.79000
#   Classification -> best τ=0.555 (val F1=0.4082)
#   Directional -> Accuracy: 0.4844, MCC: 0.0130, F1: 0.2667
#
# [39/87] Processing HSBC...
#
# Processing HSBC (Financial)...
#   Epoch 010 - train 0.65451 | val 1.34194
#   Epoch 016 - train 0.63915 | val 1.83012
#   Classification -> best τ=0.525 (val F1=0.4000)
#   Directional -> Accuracy: 0.5312, MCC: 0.0000, F1: 0.6939
#
# [40/87] Processing IEP...
#
# Processing IEP (Conglomerates)...
#   Epoch 010 - train 0.64516 | val 0.65075
#   Epoch 020 - train 0.59014 | val 0.86547
#   Classification -> best τ=0.315 (val F1=0.2902)
#   Directional -> Accuracy: 0.4688, MCC: 0.0000, F1: 0.6383
#
# [41/87] Processing INTC...
#
# Processing INTC (Technology)...
#   Epoch 010 - train 0.67066 | val 0.96106
#   Epoch 016 - train 0.63194 | val 1.27997
#   Classification -> best τ=0.505 (val F1=0.1562)
#   Directional -> Accuracy: 0.5312, MCC: 0.1796, F1: 0.1176
#
# [42/87] Processing JNJ...
#
# Processing JNJ (Healthcare)...
#   Epoch 010 - train 0.66361 | val 0.86877
#   Epoch 016 - train 0.62790 | val 1.05513
#   Classification -> best τ=0.555 (val F1=0.2831)
#   Directional -> Accuracy: 0.5469, MCC: 0.1396, F1: 0.4314
#
# [43/87] Processing JPM...
#
# Processing JPM (Financial)...
#   Epoch 010 - train 0.66108 | val 0.70216
#   Epoch 016 - train 0.62884 | val 0.80276
#   Classification -> best τ=0.530 (val F1=0.2107)
#   Directional -> Accuracy: 0.5469, MCC: 0.1372, F1: 0.1714
#
# [44/87] Processing KO...
#
# Processing KO (Consumer Goods)...
#   Epoch 010 - train 0.63425 | val 1.01035
#   Epoch 019 - train 0.57832 | val 1.07478
#   Classification -> best τ=0.420 (val F1=0.3711)
#   Directional -> Accuracy: 0.5781, MCC: 0.2246, F1: 0.2703
#
# [45/87] Processing LMT...
#
# Processing LMT (Industrial Goods)...
#   Epoch 010 - train 0.64952 | val 0.67815
#   Epoch 020 - train 0.58323 | val 0.72094
#   Classification -> best τ=0.270 (val F1=0.3191)
#   Directional -> Accuracy: 0.4844, MCC: -0.1211, F1: 0.6452
#
# [46/87] Processing MA...
#
# Processing MA (Financial)...
#   Epoch 010 - train 0.65186 | val 0.77548
#   Epoch 019 - train 0.63802 | val 0.90587
#   Classification -> best τ=0.530 (val F1=0.2774)
#   Directional -> Accuracy: 0.4844, MCC: 0.0000, F1: 0.0000
#
# [47/87] Processing MCD...
#
# Processing MCD (Services)...
#   Epoch 010 - train 0.65942 | val 0.74939
#   Epoch 019 - train 0.62406 | val 0.82152
#   Classification -> best τ=0.415 (val F1=0.2835)
#   Directional -> Accuracy: 0.5469, MCC: 0.2348, F1: 0.3830
#
# [48/87] Processing MDT...
#
# Processing MDT (Healthcare)...
#   Epoch 010 - train 0.64789 | val 0.69620
#   Epoch 020 - train 0.59671 | val 0.73778
#   Classification -> best τ=0.510 (val F1=0.3728)
#   Directional -> Accuracy: 0.5469, MCC: 0.1061, F1: 0.4082
#
# [49/87] Processing MMM...
#
# Processing MMM (Industrial Goods)...
#   Epoch 010 - train 0.67760 | val 1.75511
#   Epoch 016 - train 0.62059 | val 1.78371
#   Classification -> best τ=0.735 (val F1=0.1658)
#   Directional -> Accuracy: 0.4531, MCC: 0.0000, F1: 0.0000
#
# [50/87] Processing MO...
#
# Processing MO (Consumer Goods)...
#   Epoch 010 - train 0.65919 | val 0.74927
#   Epoch 016 - train 0.59581 | val 0.80442
#   Classification -> best τ=0.050 (val F1=0.0000)
#   Directional -> Accuracy: 0.5156, MCC: 0.0000, F1: 0.6804
#
# [51/87] Processing MRK...
#
# Processing MRK (Healthcare)...
#   Epoch 010 - train 0.63519 | val 1.21350
#   Epoch 016 - train 0.61718 | val 1.64051
#   Classification -> best τ=0.495 (val F1=0.2781)
#   Directional -> Accuracy: 0.5156, MCC: 0.0000, F1: 0.6804
#
# [52/87] Processing MSFT...
#
# Processing MSFT (Technology)...
#   Epoch 010 - train 0.66118 | val 0.78218
#   Epoch 016 - train 0.62798 | val 0.98631
#   Classification -> best τ=0.555 (val F1=0.1870)
#   Directional -> Accuracy: 0.4375, MCC: 0.0000, F1: 0.0000
#
# [53/87] Processing NEE...
#
# Processing NEE (Utilities)...
#   Epoch 010 - train 0.64290 | val 0.86834
#   Epoch 016 - train 0.59455 | val 1.21794
#   Classification -> best τ=0.600 (val F1=0.3467)
#   Directional -> Accuracy: 0.4062, MCC: 0.0000, F1: 0.0000
#
# [54/87] Processing NGG...
#
# Processing NGG (Utilities)...
#   Epoch 010 - train 0.63969 | val 0.85423
#   Epoch 016 - train 0.62578 | val 0.84494
#   Classification -> best τ=0.550 (val F1=0.1171)
#   Directional -> Accuracy: 0.5312, MCC: 0.0000, F1: 0.0000
#
# [55/87] Processing NVS...
#
# Processing NVS (Healthcare)...
#   Epoch 010 - train 0.67209 | val 0.80193
#   Epoch 016 - train 0.64282 | val 1.04590
#   Classification -> best τ=0.485 (val F1=0.2439)
#   Directional -> Accuracy: 0.4375, MCC: 0.1486, F1: 0.5909
#
# [56/87] Processing ORCL...
#
# Processing ORCL (Technology)...
#   Epoch 010 - train 0.66332 | val 0.76251
#   Epoch 016 - train 0.65195 | val 0.76784
#   Classification -> best τ=0.570 (val F1=0.1917)
#   Directional -> Accuracy: 0.4531, MCC: -0.0704, F1: 0.5882
#
# [57/87] Processing PCG...
#
# Processing PCG (Utilities)...
#   Epoch 010 - train 0.64516 | val 0.66060
#   Epoch 020 - train 0.61771 | val 0.75653
#   Classification -> best τ=0.335 (val F1=0.4824)
#   Directional -> Accuracy: 0.5156, MCC: 0.0022, F1: 0.6173
#
# [58/87] Processing PCLN...
#
# Processing PCLN (Services)...
#   Epoch 010 - train 0.63892 | val 0.65677
#   Epoch 020 - train 0.61234 | val 0.66285
#   Classification -> best τ=0.355 (val F1=0.5336)
#   Directional -> Accuracy: 0.4844, MCC: 0.0774, F1: 0.1951
#
# [59/87] Processing PEP...
#
# Processing PEP (Consumer Goods)...
#   Epoch 010 - train 0.61502 | val 1.31719
#   Epoch 016 - train 0.62686 | val 1.52791
#   Classification -> best τ=0.520 (val F1=0.3605)
#   Directional -> Accuracy: 0.6406, MCC: 0.2772, F1: 0.5490
#
# [60/87] Processing PFE...
#
# Processing PFE (Healthcare)...
#   Epoch 010 - train 0.63295 | val 0.80575
#   Epoch 016 - train 0.63456 | val 1.26983
#   Classification -> best τ=0.545 (val F1=0.2762)
#   Directional -> Accuracy: 0.5469, MCC: 0.0682, F1: 0.4314
#
# [61/87] Processing PG...
#
# Processing PG (Consumer Goods)...
#   Epoch 010 - train 0.62174 | val 1.44706
#   Epoch 016 - train 0.60334 | val 1.45718
#   Classification -> best τ=0.720 (val F1=0.3395)
#   Directional -> Accuracy: 0.4375, MCC: 0.0000, F1: 0.0000
#
# [62/87] Processing PICO...
#
# Processing PICO (Conglomerates)...
#   Epoch 010 - train 0.65787 | val 0.71804
#   Epoch 019 - train 0.61543 | val 0.74632
#   Classification -> best τ=0.520 (val F1=0.1936)
#   Directional -> Accuracy: 0.6250, MCC: 0.2632, F1: 0.5556
#
# [63/87] Processing PM...
#
# Processing PM (Consumer Goods)...
#   Epoch 010 - train 0.65596 | val 0.73024
#   Epoch 020 - train 0.57820 | val 0.76511
#   Classification -> best τ=0.590 (val F1=0.3586)
#   Directional -> Accuracy: 0.4844, MCC: 0.0602, F1: 0.1081
#
# [64/87] Processing PPL...
#
# Processing PPL (Utilities)...
#   Epoch 010 - train 0.67098 | val 0.69149
#   Epoch 017 - train 0.63090 | val 0.71079
#   Classification -> best τ=0.440 (val F1=0.3398)
#   Directional -> Accuracy: 0.5156, MCC: 0.0582, F1: 0.6593
#
# [65/87] Processing PTR...
#
# Processing PTR (Basic Matierials)...
#   Epoch 010 - train 0.65467 | val 1.19961
#   Epoch 016 - train 0.62908 | val 1.16899
#   Classification -> best τ=0.600 (val F1=0.3934)
#   Directional -> Accuracy: 0.4219, MCC: -0.1724, F1: 0.5747
#
# [66/87] Processing RDS-B...
#
# Processing RDS-B (Basic Matierials)...
#   Epoch 010 - train 0.65589 | val 1.01989
#   Epoch 016 - train 0.63728 | val 1.27973
#   Classification -> best τ=0.565 (val F1=0.2521)
#   Directional -> Accuracy: 0.4375, MCC: -0.0859, F1: 0.5909
#
# [67/87] Processing REX...
#
# Processing REX (Conglomerates)...
#   Epoch 010 - train 0.66495 | val 0.71987
#   Epoch 020 - train 0.58640 | val 0.72809
#   Classification -> best τ=0.525 (val F1=0.3536)
#   Directional -> Accuracy: 0.5312, MCC: -0.0071, F1: 0.6667
#
# [68/87] Processing SLB...
#
# Processing SLB (Basic Matierials)...
#   Epoch 010 - train 0.65024 | val 1.47919
#   Epoch 016 - train 0.60912 | val 2.09253
#   Classification -> best τ=0.480 (val F1=0.2740)
#   Directional -> Accuracy: 0.4531, MCC: 0.0000, F1: 0.6237
#
# [69/87] Processing SNP...
#
# Processing SNP (Basic Matierials)...
#   Epoch 010 - train 0.66246 | val 0.86058
#   Epoch 016 - train 0.62240 | val 1.08658
#   Classification -> best τ=0.560 (val F1=0.2236)
#   Directional -> Accuracy: 0.5312, MCC: 0.1304, F1: 0.3478
#
# [70/87] Processing SNY...
#
# Processing SNY (Healthcare)...
#   Epoch 010 - train 0.68416 | val 0.72154
#   Epoch 019 - train 0.63991 | val 0.76256
#   Classification -> best τ=0.580 (val F1=0.3349)
#   Directional -> Accuracy: 0.4531, MCC: -0.0072, F1: 0.5455
#
# [71/87] Processing SO...
#
# Processing SO (Utilities)...
#   Epoch 010 - train 0.68233 | val 0.71342
#   Epoch 017 - train 0.65492 | val 0.69039
#   Classification -> best τ=0.460 (val F1=0.2774)
#   Directional -> Accuracy: 0.5781, MCC: 0.0000, F1: 0.7327
#
# [72/87] Processing SPLP...
#
# Processing SPLP (Conglomerates)...
#   Epoch 010 - train 0.65421 | val 0.77954
#   Epoch 020 - train 0.62569 | val 0.88251
#   Classification -> best τ=0.415 (val F1=0.3706)
#   Directional -> Accuracy: 0.4531, MCC: 0.0051, F1: 0.5570
#
# [73/87] Processing SRE...
#
# Processing SRE (Utilities)...
#   Epoch 010 - train 0.64121 | val 1.07103
#   Epoch 016 - train 0.59464 | val 1.60207
#   Classification -> best τ=0.470 (val F1=0.3676)
#   Directional -> Accuracy: 0.4688, MCC: 0.0534, F1: 0.6222
#
# [74/87] Processing T...
#
# Processing T (Technology)...
#   Epoch 010 - train 0.61094 | val 0.90287
#   Epoch 016 - train 0.56415 | val 1.01422
#   Classification -> best τ=0.510 (val F1=0.2884)
#   Directional -> Accuracy: 0.5625, MCC: 0.1455, F1: 0.7021
#
# [75/87] Processing TM...
#
# Processing TM (Consumer Goods)...
#   Epoch 010 - train 0.63741 | val 0.84159
#   Epoch 016 - train 0.62283 | val 0.98078
#   Classification -> best τ=0.515 (val F1=0.3203)
#   Directional -> Accuracy: 0.4531, MCC: -0.1090, F1: 0.3396
#
# [76/87] Processing TOT...
#
# Processing TOT (Basic Matierials)...
#   Epoch 010 - train 0.65648 | val 0.67674
#   Epoch 020 - train 0.60940 | val 0.80972
#   Classification -> best τ=0.345 (val F1=0.3892)
#   Directional -> Accuracy: 0.6250, MCC: 0.1711, F1: 0.4286
#
# [77/87] Processing TSM...
#
# Processing TSM (Technology)...
#   Epoch 010 - train 0.67070 | val 0.87291
#   Epoch 018 - train 0.63472 | val 0.98634
#   Classification -> best τ=0.630 (val F1=0.2282)
#   Directional -> Accuracy: 0.5000, MCC: 0.0000, F1: 0.0000
#
# [78/87] Processing UL...
#
# Processing UL (Consumer Goods)...
#   Epoch 010 - train 0.64422 | val 0.81668
#   Epoch 016 - train 0.62593 | val 0.87297
#   Classification -> best τ=0.590 (val F1=0.2224)
#   Directional -> Accuracy: 0.5156, MCC: 0.1260, F1: 0.0606
#
# [79/87] Processing UN...
#
# Processing UN (Consumer Goods)...
#   Epoch 010 - train 0.63522 | val 0.88318
#   Epoch 016 - train 0.61137 | val 1.08991
#   Classification -> best τ=0.625 (val F1=0.2193)
#   Directional -> Accuracy: 0.5000, MCC: 0.1221, F1: 0.0588
#
# [80/87] Processing UNH...
#
# Processing UNH (Healthcare)...
#   Epoch 010 - train 0.64453 | val 0.75565
#   Epoch 020 - train 0.59829 | val 1.03336
#   Classification -> best τ=0.535 (val F1=0.3782)
#   Directional -> Accuracy: 0.5469, MCC: 0.1064, F1: 0.2564
#
# [81/87] Processing UPS...
#
# Processing UPS (Services)...
#   Epoch 010 - train 0.66572 | val 0.79740
#   Epoch 016 - train 0.65921 | val 0.89430
#   Classification -> best τ=0.525 (val F1=0.2205)
#   Directional -> Accuracy: 0.5000, MCC: 0.0000, F1: 0.3333
#
# [82/87] Processing UTX...
#
# Processing UTX (Industrial Goods)...
#   Epoch 010 - train 0.65665 | val 1.85836
#   Epoch 016 - train 0.63285 | val 2.61173
#   Classification -> best τ=0.600 (val F1=0.1353)
#   Directional -> Accuracy: 0.6250, MCC: 0.3077, F1: 0.3684
#
# [83/87] Processing V...
#
# Processing V (Financial)...
#   Epoch 010 - train 0.68260 | val 0.72242
#   Epoch 020 - train 0.61290 | val 0.81029
#   Classification -> best τ=0.430 (val F1=0.4119)
#   Directional -> Accuracy: 0.5781, MCC: 0.2253, F1: 0.4000
#
# [84/87] Processing VZ...
#
# Processing VZ (Technology)...
#   Epoch 010 - train 0.66631 | val 0.98646
#   Epoch 016 - train 0.63823 | val 1.51759
#   Classification -> best τ=0.605 (val F1=0.2439)
#   Directional -> Accuracy: 0.5625, MCC: 0.1929, F1: 0.3636
#
# [85/87] Processing WFC...
#
# Processing WFC (Financial)...
#   Epoch 010 - train 0.66521 | val 0.79874
#   Epoch 017 - train 0.58663 | val 0.86530
#   Classification -> best τ=0.505 (val F1=0.3395)
#   Directional -> Accuracy: 0.5625, MCC: 0.0992, F1: 0.4400
#
# [86/87] Processing WMT...
#
# Processing WMT (Services)...
#   Epoch 010 - train 0.63813 | val 0.88471
#   Epoch 017 - train 0.63531 | val 1.06321
#   Classification -> best τ=0.595 (val F1=0.1083)
#   Directional -> Accuracy: 0.5156, MCC: 0.0388, F1: 0.3111
#
# [87/87] Processing XOM...
#
# Processing XOM (Basic Matierials)...
#   Epoch 010 - train 0.62703 | val 1.18125
#   Epoch 020 - train 0.59111 | val 1.49265
#   Classification -> best τ=0.485 (val F1=0.2942)
#   Directional -> Accuracy: 0.4219, MCC: -0.1464, F1: 0.4638
#
# ================================================================================
# Pipeline completed: 85/87 companies processed successfully
# ================================================================================
# Skip summary:
#   no_train_window: 2
# ================================================================================
# STOCK PREDICTION PIPELINE RESULTS
# ================================================================================
# Model: GRU | Problem: classification
# Companies analyzed: 85
# Average samples per company: 935
# ==================================================
# OVERALL PERFORMANCE
# ==================================================
# Directional Accuracy:   0.5173 (±0.0600)
# Matthews Correlation:   0.0667 (±0.1181)
# F1 Score:              0.3796 (±0.2407)
# Precision:             0.5169 (±0.2717)
# Recall:                0.4328 (±0.3704)
# ==================================================
# PERFORMANCE BY SECTOR
# ==================================================
# Conglomerates        | Acc: 0.534±0.081 | MCC: 0.092 | Companies: 6
# Financial            | Acc: 0.533±0.065 | MCC: 0.061 | Companies: 10
# Healthcare           | Acc: 0.530±0.067 | MCC: 0.115 | Companies: 10
# Utilities            | Acc: 0.520±0.053 | MCC: 0.025 | Companies: 10
# Consumer Goods       | Acc: 0.519±0.059 | MCC: 0.083 | Companies: 10
# Industrial Goods     | Acc: 0.519±0.065 | MCC: 0.120 | Companies: 10
# Services             | Acc: 0.512±0.038 | MCC: 0.067 | Companies: 9
# Technology           | Acc: 0.511±0.052 | MCC: 0.067 | Companies: 10
# Basic Matierials     | Acc: 0.484±0.070 | MCC: -0.020 | Companies: 10
# ==================================================
# TOP 10 PERFORMERS (by Directional Accuracy)
# ==================================================
# ABBV                 | Healthcare      | Acc: 0.672 | MCC: 0.359
# CODI                 | Conglomerates   | Acc: 0.641 | MCC: 0.278
# PEP                  | Consumer Goods  | Acc: 0.641 | MCC: 0.277
# BA                   | Industrial Goods | Acc: 0.625 | MCC: 0.355
# BSAC                 | Financial       | Acc: 0.625 | MCC: 0.293
# PICO                 | Conglomerates   | Acc: 0.625 | MCC: 0.263
# TOT                  | Basic Matierials | Acc: 0.625 | MCC: 0.171
# UTX                  | Industrial Goods | Acc: 0.625 | MCC: 0.308
# AEP                  | Utilities       | Acc: 0.578 | MCC: -0.104
# BAC                  | Financial       | Acc: 0.578 | MCC: 0.000
# Saved results for GRU to /mnt/primary/benchmarking/meta-results/classification/base
# ========================= RUNNING TOP BiGRU (meta) | 1H =========================
# Pipeline initialized for a 'classification' problem with horizon 1 steps. Device: cuda
# Processing 87 companies with BiGRU model...
# Problem type: classification
# Sequence length: 20
# Features: ['open', 'high', 'low', 'close', 'volume', 'roll_ret_1d', 'roll_ret_5d', 'roll_ret_20d', 'ema_12', 'ema_26', 'ema_50', 'macd_12_26_9', 'macdh_12_26_9', 'macds_12_26_9', 'rsi_14', 'stochrsik_14_14_3_3', 'stochrsid_14_14_3_3', 'atrr_14', 'bb_upper', 'bb_middle', 'bb_lower', 'obv', 'reg_pred_ret_1d_LSTM', 'reg_pred_ret_1d_BiLSTM', 'reg_pred_ret_1d_GRU', 'reg_pred_ret_1d_BiGRU', 'cls_prob_up_1d_LSTM', 'cls_prob_up_1d_BiLSTM', 'cls_prob_up_1d_GRU', 'cls_prob_up_1d_BiGRU']
#
# [1/87] Processing AAPL...
#
# Processing AAPL (Consumer Goods)...
#   Epoch 010 - train 0.65506 | val 0.93643
#   Epoch 020 - train 0.54084 | val 2.01999
#   Epoch 021 - train 0.51607 | val 2.16316
#   Classification -> best τ=0.455 (val F1=0.3478)
#   Directional -> Accuracy: 0.5625, MCC: 0.1183, F1: 0.5172
#
# [2/87] Processing ABB...
#
# Processing ABB (Industrial Goods)...
#   Epoch 010 - train 0.63282 | val 0.82134
#   Epoch 017 - train 0.54789 | val 1.58182
#   Classification -> best τ=0.475 (val F1=0.2418)
#   Directional -> Accuracy: 0.5938, MCC: 0.2037, F1: 0.7347
#
# [3/87] Processing ABBV...
#
# Processing ABBV (Healthcare)...
#   Epoch 010 - train 0.64260 | val 0.68603
#   Epoch 020 - train 0.56998 | val 0.91144
#   Epoch 021 - train 0.57686 | val 0.92076
#   Classification -> best τ=0.690 (val F1=0.3052)
#   Directional -> Accuracy: 0.6250, MCC: 0.3254, F1: 0.5200
#
# [4/87] Processing AEP...
#
# Processing AEP (Utilities)...
#   Epoch 010 - train 0.65673 | val 0.73305
#   Epoch 017 - train 0.56960 | val 0.84291
#   Classification -> best τ=0.545 (val F1=0.3597)
#   Directional -> Accuracy: 0.4375, MCC: -0.0486, F1: 0.3571
#
# [5/87] Processing AGFS...
#
# Processing AGFS (Conglomerates)...
# No training data in range for AGFS. Skipping...
#
# [6/87] Processing AMGN...
#
# Processing AMGN (Healthcare)...
#   Epoch 010 - train 0.62403 | val 0.68172
#   Epoch 020 - train 0.50039 | val 1.65096
#   Classification -> best τ=0.465 (val F1=0.3803)
#   Directional -> Accuracy: 0.4531, MCC: 0.0466, F1: 0.1026
#
# [7/87] Processing AMZN...
#
# Processing AMZN (Services)...
#   Epoch 010 - train 0.66299 | val 0.82498
#   Epoch 018 - train 0.60698 | val 1.08248
#   Classification -> best τ=0.505 (val F1=0.3855)
#   Directional -> Accuracy: 0.4531, MCC: 0.0000, F1: 0.0000
#
# [8/87] Processing BA...
#
# Processing BA (Industrial Goods)...
#   Epoch 010 - train 0.65682 | val 0.78434
#   Epoch 020 - train 0.53226 | val 0.92746
#   Classification -> best τ=0.625 (val F1=0.4045)
#   Directional -> Accuracy: 0.4531, MCC: 0.0000, F1: 0.0000
#
# [9/87] Processing BABA...
#
# Processing BABA (Services)...
# No training data in range for BABA. Skipping...
#
# [10/87] Processing BAC...
#
# Processing BAC (Financial)...
#   Epoch 010 - train 0.65276 | val 0.89924
#   Epoch 016 - train 0.62078 | val 1.04645
#   Classification -> best τ=0.565 (val F1=0.2582)
#   Directional -> Accuracy: 0.5781, MCC: 0.0000, F1: 0.0000
#
# [11/87] Processing BBL...
#
# Processing BBL (Basic Matierials)...
#   Epoch 010 - train 0.65954 | val 0.69507
#   Epoch 020 - train 0.58835 | val 0.91799
#   Classification -> best τ=0.475 (val F1=0.3319)
#   Directional -> Accuracy: 0.4688, MCC: 0.0465, F1: 0.5278
#
# [12/87] Processing BCH...
#
# Processing BCH (Financial)...
#   Epoch 010 - train 0.65971 | val 0.67278
#   Epoch 020 - train 0.56622 | val 0.69398
#   Epoch 021 - train 0.57106 | val 0.67999
#   Classification -> best τ=0.675 (val F1=0.4065)
#   Directional -> Accuracy: 0.6094, MCC: 0.1644, F1: 0.4186
#
# [13/87] Processing BHP...
#
# Processing BHP (Basic Matierials)...
#   Epoch 010 - train 0.64292 | val 0.71515
#   Epoch 020 - train 0.54009 | val 0.76531
#   Epoch 022 - train 0.53475 | val 0.76928
#   Classification -> best τ=0.475 (val F1=0.4472)
#   Directional -> Accuracy: 0.4844, MCC: -0.0120, F1: 0.4923
#
# [14/87] Processing BP...
#
# Processing BP (Basic Matierials)...
#   Epoch 010 - train 0.66139 | val 0.70007
#   Epoch 020 - train 0.56937 | val 1.79517
#   Epoch 028 - train 0.49345 | val 1.71565
#   Classification -> best τ=0.630 (val F1=0.4045)
#   Directional -> Accuracy: 0.6094, MCC: 0.1523, F1: 0.0741
#
# [15/87] Processing BRK-A...
#
# Processing BRK-A (Financial)...
#   Epoch 010 - train 0.66188 | val 0.97147
#   Epoch 016 - train 0.59320 | val 1.26045
#   Classification -> best τ=0.405 (val F1=0.2571)
#   Directional -> Accuracy: 0.5000, MCC: 0.2277, F1: 0.6364
#
# [16/87] Processing BSAC...
#
# Processing BSAC (Financial)...
#   Epoch 010 - train 0.65993 | val 0.84493
#   Epoch 016 - train 0.63834 | val 0.85400
#   Classification -> best τ=0.050 (val F1=0.0000)
#   Directional -> Accuracy: 0.4375, MCC: 0.0000, F1: 0.6087
#
# [17/87] Processing BUD...
#
# Processing BUD (Consumer Goods)...
#   Epoch 010 - train 0.66693 | val 0.80860
#   Epoch 018 - train 0.58246 | val 1.03317
#   Classification -> best τ=0.445 (val F1=0.3706)
#   Directional -> Accuracy: 0.5156, MCC: 0.0369, F1: 0.6173
#
# [18/87] Processing C...
#
# Processing C (Financial)...
#   Epoch 010 - train 0.62425 | val 0.86568
#   Epoch 020 - train 0.51219 | val 1.45480
#   Epoch 023 - train 0.49064 | val 1.67344
#   Classification -> best τ=0.205 (val F1=0.3093)
#   Directional -> Accuracy: 0.4062, MCC: 0.0000, F1: 0.5778
#
# [19/87] Processing CAT...
#
# Processing CAT (Industrial Goods)...
#   Epoch 010 - train 0.62897 | val 0.68604
#   Epoch 020 - train 0.51522 | val 1.01984
#   Epoch 026 - train 0.46379 | val 1.38048
#   Classification -> best τ=0.615 (val F1=0.2383)
#   Directional -> Accuracy: 0.5000, MCC: 0.0000, F1: 0.2000
#
# [20/87] Processing CELG...
#
# Processing CELG (Healthcare)...
#   Epoch 010 - train 0.63449 | val 0.68410
#   Epoch 020 - train 0.54844 | val 0.83181
#   Epoch 021 - train 0.54136 | val 0.86519
#   Classification -> best τ=0.555 (val F1=0.4122)
#   Directional -> Accuracy: 0.5781, MCC: 0.1749, F1: 0.5091
#
# [21/87] Processing CHL...
#
# Processing CHL (Technology)...
#   Epoch 010 - train 0.63864 | val 0.72230
#   Epoch 019 - train 0.55816 | val 0.73087
#   Classification -> best τ=0.540 (val F1=0.2460)
#   Directional -> Accuracy: 0.5000, MCC: -0.0196, F1: 0.3043
#
# [22/87] Processing CHTR...
#
# Processing CHTR (Services)...
#   Epoch 010 - train 0.67079 | val 0.65718
#   Epoch 020 - train 0.62578 | val 0.69549
#   Epoch 021 - train 0.59811 | val 0.70647
#   Classification -> best τ=0.385 (val F1=0.4201)
#   Directional -> Accuracy: 0.5000, MCC: 0.0000, F1: 0.6667
#
# [23/87] Processing CMCSA...
#
# Processing CMCSA (Services)...
#   Epoch 010 - train 0.62859 | val 0.84486
#   Epoch 018 - train 0.51111 | val 0.91817
#   Classification -> best τ=0.535 (val F1=0.4045)
#   Directional -> Accuracy: 0.5781, MCC: 0.1724, F1: 0.2703
#
# [24/87] Processing CODI...
#
# Processing CODI (Conglomerates)...
#   Epoch 010 - train 0.62153 | val 0.89184
#   Epoch 016 - train 0.55989 | val 1.00008
#   Classification -> best τ=0.540 (val F1=0.1718)
#   Directional -> Accuracy: 0.5781, MCC: 0.1540, F1: 0.1818
#
# [25/87] Processing CSCO...
#
# Processing CSCO (Technology)...
#   Epoch 010 - train 0.66480 | val 0.72024
#   Epoch 019 - train 0.57764 | val 1.21930
#   Classification -> best τ=0.605 (val F1=0.3536)
#   Directional -> Accuracy: 0.5156, MCC: 0.1260, F1: 0.0606
#
# [26/87] Processing CVX...
#
# Processing CVX (Basic Matierials)...
#   Epoch 010 - train 0.64808 | val 0.97318
#   Epoch 016 - train 0.61765 | val 1.23155
#   Classification -> best τ=0.545 (val F1=0.3244)
#   Directional -> Accuracy: 0.5312, MCC: 0.0000, F1: 0.0000
#
# [27/87] Processing D...
#
# Processing D (Utilities)...
#   Epoch 010 - train 0.62415 | val 1.02016
#   Epoch 018 - train 0.49170 | val 1.19140
#   Classification -> best τ=0.355 (val F1=0.3570)
#   Directional -> Accuracy: 0.5469, MCC: 0.2218, F1: 0.6882
#
# [28/87] Processing DHR...
#
# Processing DHR (Industrial Goods)...
#   Epoch 010 - train 0.66696 | val 0.79670
#   Epoch 018 - train 0.59155 | val 0.91677
#   Classification -> best τ=0.390 (val F1=0.2697)
#   Directional -> Accuracy: 0.5156, MCC: 0.0355, F1: 0.4918
#
# [29/87] Processing DIS...
#
# Processing DIS (Services)...
#   Epoch 010 - train 0.62992 | val 1.68964
#   Epoch 016 - train 0.59411 | val 2.21816
#   Classification -> best τ=0.655 (val F1=0.2697)
#   Directional -> Accuracy: 0.5469, MCC: 0.0000, F1: 0.7071
#
# [30/87] Processing DUK...
#
# Processing DUK (Utilities)...
#   Epoch 010 - train 0.64826 | val 0.78212
#   Epoch 019 - train 0.53586 | val 0.88188
#   Classification -> best τ=0.400 (val F1=0.2383)
#   Directional -> Accuracy: 0.5938, MCC: 0.1050, F1: 0.7292
#
# [31/87] Processing EXC...
#
# Processing EXC (Utilities)...
#   Epoch 010 - train 0.66859 | val 1.02471
#   Epoch 018 - train 0.59469 | val 1.39638
#   Classification -> best τ=0.295 (val F1=0.2644)
#   Directional -> Accuracy: 0.5000, MCC: 0.0000, F1: 0.6667
#
# [32/87] Processing FB...
#
# Processing FB (Technology)...
#   Epoch 010 - train 0.64065 | val 0.90459
#   Epoch 016 - train 0.59954 | val 1.13758
#   Classification -> best τ=0.620 (val F1=0.4571)
#   Directional -> Accuracy: 0.4531, MCC: -0.0169, F1: 0.0541
#
# [33/87] Processing GD...
#
# Processing GD (Industrial Goods)...
#   Epoch 010 - train 0.65908 | val 0.88531
#   Epoch 018 - train 0.59875 | val 1.14095
#   Classification -> best τ=0.405 (val F1=0.2864)
#   Directional -> Accuracy: 0.3906, MCC: -0.1955, F1: 0.5412
#
# [34/87] Processing GE...
#
# Processing GE (Industrial Goods)...
#   Epoch 010 - train 0.61304 | val 0.88210
#   Epoch 018 - train 0.54028 | val 1.18076
#   Classification -> best τ=0.455 (val F1=0.3676)
#   Directional -> Accuracy: 0.4688, MCC: 0.1894, F1: 0.1500
#
# [35/87] Processing GOOG...
#
# Processing GOOG (Technology)...
#   Epoch 010 - train 0.60820 | val 0.77475
#   Epoch 016 - train 0.56138 | val 0.74022
#   Classification -> best τ=0.380 (val F1=0.4045)
#   Directional -> Accuracy: 0.5000, MCC: 0.1687, F1: 0.1111
#
# [36/87] Processing HD...
#
# Processing HD (Services)...
#   Epoch 010 - train 0.65954 | val 0.73793
#   Epoch 020 - train 0.56162 | val 0.95762
#   Classification -> best τ=0.460 (val F1=0.2582)
#   Directional -> Accuracy: 0.5312, MCC: -0.0966, F1: 0.6809
#
# [37/87] Processing HON...
#
# Processing HON (Industrial Goods)...
#   Epoch 010 - train 0.63455 | val 0.93969
#   Epoch 017 - train 0.54948 | val 1.13187
#   Classification -> best τ=0.535 (val F1=0.3637)
#   Directional -> Accuracy: 0.6250, MCC: 0.3203, F1: 0.4545
#
# [38/87] Processing HRG...
#
# Processing HRG (Conglomerates)...
#   Epoch 010 - train 0.64509 | val 0.67632
#   Epoch 020 - train 0.57227 | val 0.70792
#   Classification -> best τ=0.505 (val F1=0.2661)
#   Directional -> Accuracy: 0.5312, MCC: 0.1183, F1: 0.3750
#
# [39/87] Processing HSBC...
#
# Processing HSBC (Financial)...
#   Epoch 010 - train 0.62982 | val 1.63034
#   Epoch 016 - train 0.57071 | val 2.39687
#   Classification -> best τ=0.435 (val F1=0.1844)
#   Directional -> Accuracy: 0.5312, MCC: 0.0000, F1: 0.6939
#
# [40/87] Processing IEP...
#
# Processing IEP (Conglomerates)...
#   Epoch 010 - train 0.63836 | val 0.63388
#   Epoch 020 - train 0.59289 | val 0.59770
#   Epoch 030 - train 0.56402 | val 0.70467
#   Classification -> best τ=0.485 (val F1=0.4519)
#   Directional -> Accuracy: 0.5312, MCC: 0.0331, F1: 0.3182
#
# [41/87] Processing INTC...
#
# Processing INTC (Technology)...
#   Epoch 010 - train 0.63974 | val 0.86403
#   Epoch 017 - train 0.57792 | val 1.30831
#   Classification -> best τ=0.585 (val F1=0.3030)
#   Directional -> Accuracy: 0.5312, MCC: 0.1796, F1: 0.1176
#
# [42/87] Processing JNJ...
#
# Processing JNJ (Healthcare)...
#   Epoch 010 - train 0.64959 | val 0.99373
#   Epoch 018 - train 0.60201 | val 1.26811
#   Classification -> best τ=0.495 (val F1=0.2582)
#   Directional -> Accuracy: 0.5469, MCC: 0.1162, F1: 0.4912
#
# [43/87] Processing JPM...
#
# Processing JPM (Financial)...
#   Epoch 010 - train 0.60956 | val 1.18619
#   Epoch 017 - train 0.57924 | val 1.47140
#   Classification -> best τ=0.655 (val F1=0.2582)
#   Directional -> Accuracy: 0.5312, MCC: 0.0545, F1: 0.4000
#
# [44/87] Processing KO...
#
# Processing KO (Consumer Goods)...
#   Epoch 010 - train 0.66419 | val 0.76411
#   Epoch 020 - train 0.54930 | val 0.96453
#   Classification -> best τ=0.360 (val F1=0.3711)
#   Directional -> Accuracy: 0.6250, MCC: 0.2633, F1: 0.6571
#
# [45/87] Processing LMT...
#
# Processing LMT (Industrial Goods)...
#   Epoch 010 - train 0.63151 | val 0.76400
#   Epoch 020 - train 0.49178 | val 1.33475
#   Classification -> best τ=0.380 (val F1=0.2835)
#   Directional -> Accuracy: 0.5469, MCC: 0.1588, F1: 0.3256
#
# [46/87] Processing MA...
#
# Processing MA (Financial)...
#   Epoch 010 - train 0.64407 | val 0.78913
#   Epoch 017 - train 0.56295 | val 0.97294
#   Classification -> best τ=0.495 (val F1=0.2206)
#   Directional -> Accuracy: 0.5156, MCC: 0.0101, F1: 0.6593
#
# [47/87] Processing MCD...
#
# Processing MCD (Services)...
#   Epoch 010 - train 0.63905 | val 0.79977
#   Epoch 016 - train 0.60536 | val 1.07027
#   Classification -> best τ=0.570 (val F1=0.2460)
#   Directional -> Accuracy: 0.4375, MCC: 0.0000, F1: 0.0000
#
# [48/87] Processing MDT...
#
# Processing MDT (Healthcare)...
#   Epoch 010 - train 0.62123 | val 0.89153
#   Epoch 019 - train 0.52978 | val 1.16321
#   Classification -> best τ=0.415 (val F1=0.2810)
#   Directional -> Accuracy: 0.5781, MCC: 0.1844, F1: 0.6667
#
# [49/87] Processing MMM...
#
# Processing MMM (Industrial Goods)...
#   Epoch 010 - train 0.66298 | val 1.01457
#   Epoch 016 - train 0.59427 | val 1.15825
#   Classification -> best τ=0.455 (val F1=0.1419)
#   Directional -> Accuracy: 0.5469, MCC: 0.0169, F1: 0.7010
#
# [50/87] Processing MO...
#
# Processing MO (Consumer Goods)...
#   Epoch 010 - train 0.62750 | val 0.81683
#   Epoch 019 - train 0.53846 | val 1.51762
#   Classification -> best τ=0.500 (val F1=0.2722)
#   Directional -> Accuracy: 0.5000, MCC: 0.0491, F1: 0.1579
#
# [51/87] Processing MRK...
#
# Processing MRK (Healthcare)...
#   Epoch 010 - train 0.64706 | val 1.27139
#   Epoch 017 - train 0.60143 | val 2.05480
#   Classification -> best τ=0.405 (val F1=0.2343)
#   Directional -> Accuracy: 0.5156, MCC: 0.0000, F1: 0.6804
#
# [52/87] Processing MSFT...
#
# Processing MSFT (Technology)...
#   Epoch 010 - train 0.63204 | val 0.88563
#   Epoch 016 - train 0.60723 | val 1.19699
#   Classification -> best τ=0.555 (val F1=0.3341)
#   Directional -> Accuracy: 0.4375, MCC: 0.0000, F1: 0.0000
#
# [53/87] Processing NEE...
#
# Processing NEE (Utilities)...
#   Epoch 010 - train 0.65784 | val 0.63993
#   Epoch 020 - train 0.59565 | val 0.77128
#   Epoch 030 - train 0.49103 | val 0.83319
#   Classification -> best τ=0.800 (val F1=0.4744)
#   Directional -> Accuracy: 0.4219, MCC: 0.1042, F1: 0.0513
#
# [54/87] Processing NGG...
#
# Processing NGG (Utilities)...
#   Epoch 010 - train 0.62053 | val 1.08426
#   Epoch 018 - train 0.52740 | val 1.78417
#   Classification -> best τ=0.480 (val F1=0.2759)
#   Directional -> Accuracy: 0.5312, MCC: 0.0000, F1: 0.0000
#
# [55/87] Processing NVS...
#
# Processing NVS (Healthcare)...
#   Epoch 010 - train 0.67311 | val 0.67004
#   Epoch 020 - train 0.58951 | val 0.64103
#   Epoch 030 - train 0.47202 | val 0.74357
#   Classification -> best τ=0.175 (val F1=0.3616)
#   Directional -> Accuracy: 0.4062, MCC: 0.0000, F1: 0.5778
#
# [56/87] Processing ORCL...
#
# Processing ORCL (Technology)...
#   Epoch 010 - train 0.64585 | val 0.69225
#   Epoch 020 - train 0.55973 | val 0.72797
#   Epoch 025 - train 0.52015 | val 0.69915
#   Classification -> best τ=0.560 (val F1=0.2236)
#   Directional -> Accuracy: 0.5469, MCC: 0.0721, F1: 0.2162
#
# [57/87] Processing PCG...
#
# Processing PCG (Utilities)...
#   Epoch 010 - train 0.64158 | val 0.86592
#   Epoch 018 - train 0.60627 | val 1.12357
#   Classification -> best τ=0.665 (val F1=0.1754)
#   Directional -> Accuracy: 0.4688, MCC: 0.0000, F1: 0.0000
#
# [58/87] Processing PCLN...
#
# Processing PCLN (Services)...
#   Epoch 010 - train 0.63131 | val 0.77796
#   Epoch 017 - train 0.59563 | val 1.00694
#   Classification -> best τ=0.450 (val F1=0.3478)
#   Directional -> Accuracy: 0.5781, MCC: 0.1269, F1: 0.6747
#
# [59/87] Processing PEP...
#
# Processing PEP (Consumer Goods)...
#   Epoch 010 - train 0.60779 | val 2.19809
#   Epoch 019 - train 0.52805 | val 3.10151
#   Classification -> best τ=0.470 (val F1=0.3605)
#   Directional -> Accuracy: 0.5938, MCC: 0.1815, F1: 0.5517
#
# [60/87] Processing PFE...
#
# Processing PFE (Healthcare)...
#   Epoch 010 - train 0.64165 | val 0.97812
#   Epoch 017 - train 0.61460 | val 1.16121
#   Classification -> best τ=0.605 (val F1=0.2901)
#   Directional -> Accuracy: 0.5625, MCC: 0.0832, F1: 0.2632
#
# [61/87] Processing PG...
#
# Processing PG (Consumer Goods)...
#   Epoch 010 - train 0.61103 | val 2.60392
#   Epoch 016 - train 0.57358 | val 3.07526
#   Classification -> best τ=0.565 (val F1=0.4201)
#   Directional -> Accuracy: 0.5156, MCC: 0.2081, F1: 0.2791
#
# [62/87] Processing PICO...
#
# Processing PICO (Conglomerates)...
#   Epoch 010 - train 0.62810 | val 0.98641
#   Epoch 018 - train 0.57277 | val 1.10991
#   Classification -> best τ=0.385 (val F1=0.1936)
#   Directional -> Accuracy: 0.5000, MCC: 0.0000, F1: 0.6667
#
# [63/87] Processing PM...
#
# Processing PM (Consumer Goods)...
#   Epoch 010 - train 0.65070 | val 0.72954
#   Epoch 020 - train 0.51373 | val 0.84122
#   Epoch 022 - train 0.47820 | val 0.88405
#   Classification -> best τ=0.610 (val F1=0.3685)
#   Directional -> Accuracy: 0.4844, MCC: 0.0602, F1: 0.1081
#
# [64/87] Processing PPL...
#
# Processing PPL (Utilities)...
#   Epoch 010 - train 0.66378 | val 0.66952
#   Epoch 020 - train 0.57387 | val 0.71938
#   Epoch 023 - train 0.53711 | val 0.71052
#   Classification -> best τ=0.305 (val F1=0.4353)
#   Directional -> Accuracy: 0.6406, MCC: 0.2882, F1: 0.5965
#
# [65/87] Processing PTR...
#
# Processing PTR (Basic Matierials)...
#   Epoch 010 - train 0.66993 | val 0.98940
#   Epoch 020 - train 0.56453 | val 1.36997
#   Epoch 023 - train 0.51524 | val 1.40905
#   Classification -> best τ=0.515 (val F1=0.3922)
#   Directional -> Accuracy: 0.4375, MCC: -0.1088, F1: 0.5263
#
# [66/87] Processing RDS-B...
#
# Processing RDS-B (Basic Matierials)...
#   Epoch 010 - train 0.63898 | val 2.71661
#   Epoch 016 - train 0.57625 | val 3.88290
#   Classification -> best τ=0.050 (val F1=0.0000)
#   Directional -> Accuracy: 0.4531, MCC: 0.0000, F1: 0.6237
#
# [67/87] Processing REX...
#
# Processing REX (Conglomerates)...
#   Epoch 010 - train 0.64503 | val 0.85693
#   Epoch 017 - train 0.56773 | val 0.83910
#   Classification -> best τ=0.285 (val F1=0.1754)
#   Directional -> Accuracy: 0.5469, MCC: 0.0000, F1: 0.7071
#
# [68/87] Processing SLB...
#
# Processing SLB (Basic Matierials)...
#   Epoch 010 - train 0.62217 | val 1.75116
#   Epoch 016 - train 0.57652 | val 2.43420
#   Classification -> best τ=0.410 (val F1=0.2095)
#   Directional -> Accuracy: 0.6250, MCC: 0.2433, F1: 0.5862
#
# [69/87] Processing SNP...
#
# Processing SNP (Basic Matierials)...
#   Epoch 010 - train 0.60855 | val 0.74008
#   Epoch 017 - train 0.56072 | val 0.89071
#   Classification -> best τ=0.445 (val F1=0.1054)
#   Directional -> Accuracy: 0.4375, MCC: -0.2604, F1: 0.6000
#
# [70/87] Processing SNY...
#
# Processing SNY (Healthcare)...
#   Epoch 010 - train 0.64662 | val 0.75824
#   Epoch 020 - train 0.60690 | val 0.71816
#   Epoch 022 - train 0.58276 | val 0.70792
#   Classification -> best τ=0.490 (val F1=0.3631)
#   Directional -> Accuracy: 0.4219, MCC: 0.0000, F1: 0.5934
#
# [71/87] Processing SO...
#
# Processing SO (Utilities)...
#   Epoch 010 - train 0.68749 | val 0.72410
#   Epoch 019 - train 0.60779 | val 0.74106
#   Classification -> best τ=0.365 (val F1=0.2236)
#   Directional -> Accuracy: 0.5781, MCC: 0.0000, F1: 0.7327
#
# [72/87] Processing SPLP...
#
# Processing SPLP (Conglomerates)...
#   Epoch 010 - train 0.65439 | val 0.74371
#   Epoch 020 - train 0.59843 | val 0.77985
#   Epoch 024 - train 0.55226 | val 0.75362
#   Classification -> best τ=0.385 (val F1=0.2622)
#   Directional -> Accuracy: 0.4375, MCC: 0.0398, F1: 0.5909
#
# [73/87] Processing SRE...
#
# Processing SRE (Utilities)...
#   Epoch 010 - train 0.63014 | val 1.00619
#   Epoch 016 - train 0.56627 | val 1.32747
#   Classification -> best τ=0.475 (val F1=0.2901)
#   Directional -> Accuracy: 0.4531, MCC: -0.0243, F1: 0.6067
#
# [74/87] Processing T...
#
# Processing T (Technology)...
#   Epoch 010 - train 0.61039 | val 0.84118
#   Epoch 020 - train 0.52523 | val 0.77085
#   Classification -> best τ=0.540 (val F1=0.3131)
#   Directional -> Accuracy: 0.5469, MCC: 0.0766, F1: 0.6882
#
# [75/87] Processing TM...
#
# Processing TM (Consumer Goods)...
#   Epoch 010 - train 0.61995 | val 1.25109
#   Epoch 018 - train 0.55366 | val 1.39818
#   Classification -> best τ=0.430 (val F1=0.4064)
#   Directional -> Accuracy: 0.4844, MCC: 0.0000, F1: 0.6526
#
# [76/87] Processing TOT...
#
# Processing TOT (Basic Matierials)...
#   Epoch 010 - train 0.64985 | val 0.70599
#   Epoch 020 - train 0.55159 | val 1.03499
#   Epoch 021 - train 0.54867 | val 1.09783
#   Classification -> best τ=0.395 (val F1=0.3093)
#   Directional -> Accuracy: 0.5000, MCC: 0.1654, F1: 0.5789
#
# [77/87] Processing TSM...
#
# Processing TSM (Technology)...
#   Epoch 010 - train 0.65380 | val 0.87946
#   Epoch 016 - train 0.59110 | val 0.97142
#   Classification -> best τ=0.565 (val F1=0.2706)
#   Directional -> Accuracy: 0.4844, MCC: -0.0501, F1: 0.1538
#
# [78/87] Processing UL...
#
# Processing UL (Consumer Goods)...
#   Epoch 010 - train 0.65917 | val 0.89003
#   Epoch 020 - train 0.57320 | val 1.12699
#   Epoch 023 - train 0.56506 | val 1.22165
#   Classification -> best τ=0.685 (val F1=0.2712)
#   Directional -> Accuracy: 0.5469, MCC: 0.1747, F1: 0.2162
#
# [79/87] Processing UN...
#
# Processing UN (Consumer Goods)...
#   Epoch 010 - train 0.64787 | val 0.87847
#   Epoch 018 - train 0.55352 | val 1.11724
#   Classification -> best τ=0.635 (val F1=0.2567)
#   Directional -> Accuracy: 0.5312, MCC: 0.2149, F1: 0.1667
#
# [80/87] Processing UNH...
#
# Processing UNH (Healthcare)...
#   Epoch 010 - train 0.64948 | val 0.68757
#   Epoch 020 - train 0.56399 | val 1.01654
#   Epoch 021 - train 0.55592 | val 1.03883
#   Classification -> best τ=0.605 (val F1=0.4207)
#   Directional -> Accuracy: 0.5938, MCC: 0.2018, F1: 0.4348
#
# [81/87] Processing UPS...
#
# Processing UPS (Services)...
#   Epoch 010 - train 0.65815 | val 0.78720
#   Epoch 018 - train 0.60730 | val 0.89607
#   Classification -> best τ=0.525 (val F1=0.1589)
#   Directional -> Accuracy: 0.5312, MCC: 0.1072, F1: 0.2105
#
# [82/87] Processing UTX...
#
# Processing UTX (Industrial Goods)...
#   Epoch 010 - train 0.64806 | val 2.33640
#   Epoch 016 - train 0.59994 | val 3.52377
#   Classification -> best τ=0.330 (val F1=0.0700)
#   Directional -> Accuracy: 0.5000, MCC: -0.0362, F1: 0.3043
#
# [83/87] Processing V...
#
# Processing V (Financial)...
#   Epoch 010 - train 0.65541 | val 0.74895
#   Epoch 020 - train 0.58014 | val 1.71078
#   Epoch 022 - train 0.55795 | val 1.89987
#   Classification -> best τ=0.425 (val F1=0.3225)
#   Directional -> Accuracy: 0.5156, MCC: 0.1211, F1: 0.1622
#
# [84/87] Processing VZ...
#
# Processing VZ (Technology)...
#   Epoch 010 - train 0.64061 | val 0.89064
#   Epoch 017 - train 0.60221 | val 0.99981
#   Classification -> best τ=0.460 (val F1=0.2681)
#   Directional -> Accuracy: 0.5625, MCC: 0.1612, F1: 0.6889
#
# [85/87] Processing WFC...
#
# Processing WFC (Financial)...
#   Epoch 010 - train 0.64599 | val 0.73951
#   Epoch 016 - train 0.56615 | val 0.89743
#   Classification -> best τ=0.690 (val F1=0.3395)
#   Directional -> Accuracy: 0.5469, MCC: 0.0000, F1: 0.0000
#
# [86/87] Processing WMT...
#
# Processing WMT (Services)...
#   Epoch 010 - train 0.65161 | val 0.91962
# ...
#   Epoch 010 - train 0.33884 | val 1.95503
#   Epoch 020 - train 0.21952 | val 3.92536
#   Epoch 027 - train 0.08993 | val 4.05207
#   Classification -> best τ=0.710 (val F1=0.3333)
#   Directional -> Accuracy: 0.6719, MCC: 0.1741, F1: 0.0870
#
# [67/87] Processing REX...
#
# Processing REX (Conglomerates)...
#   Epoch 010 - train 0.38881 | val 1.43806
#   Epoch 020 - train 0.11705 | val 2.61686
#   Epoch 026 - train 0.07028 | val 3.54072
#   Classification -> best τ=0.550 (val F1=0.4690)
#   Directional -> Accuracy: 0.5469, MCC: 0.0000, F1: 0.7071
#
# [68/87] Processing SLB...
#
# Processing SLB (Basic Matierials)...
#   Epoch 010 - train 0.33691 | val 2.73752
#   Epoch 020 - train 0.15012 | val 5.13160
#   Epoch 021 - train 0.14350 | val 3.99371
#   Classification -> best τ=0.615 (val F1=0.1754)
#   Directional -> Accuracy: 0.4375, MCC: 0.0000, F1: 0.6087
#
# [69/87] Processing SNP...
#
# Processing SNP (Basic Matierials)...
#   Epoch 010 - train 0.32862 | val 2.00385
#   Epoch 020 - train 0.11857 | val 1.21310
#   Epoch 029 - train 0.06350 | val 2.01508
#   Classification -> best τ=0.425 (val F1=0.3746)
#   Directional -> Accuracy: 0.4375, MCC: -0.1042, F1: 0.4194
#
# [70/87] Processing SNY...
#
# Processing SNY (Healthcare)...
#   Epoch 010 - train 0.31049 | val 1.95560
#   Epoch 020 - train 0.11941 | val 1.89715
#   Epoch 021 - train 0.10885 | val 2.06289
#   Classification -> best τ=0.550 (val F1=0.5518)
#   Directional -> Accuracy: 0.5156, MCC: 0.0369, F1: 0.6173
#
# [71/87] Processing SO...
#
# Processing SO (Utilities)...
#   Epoch 010 - train 0.38768 | val 0.84214
#   Epoch 020 - train 0.17505 | val 1.84975
#   Epoch 021 - train 0.14908 | val 1.93666
#   Classification -> best τ=0.320 (val F1=0.6183)
#   Directional -> Accuracy: 0.7188, MCC: 0.4185, F1: 0.7632
#
# [72/87] Processing SPLP...
#
# Processing SPLP (Conglomerates)...
#   Epoch 010 - train 0.36158 | val 2.87452
#   Epoch 020 - train 0.20934 | val 4.64446
#   Epoch 021 - train 0.17090 | val 4.96021
#   Classification -> best τ=0.360 (val F1=0.2178)
#   Directional -> Accuracy: 0.3906, MCC: -0.0580, F1: 0.5063
#
# [73/87] Processing SRE...
#
# Processing SRE (Utilities)...
#   Epoch 010 - train 0.31561 | val 3.17941
#   Epoch 020 - train 0.11372 | val 4.16784
#   Epoch 021 - train 0.10591 | val 4.38042
#   Classification -> best τ=0.950 (val F1=0.5827)
#   Directional -> Accuracy: 0.5625, MCC: 0.1912, F1: 0.1250
#
# [74/87] Processing T...
#
# Processing T (Technology)...
#   Epoch 010 - train 0.31620 | val 1.60589
#   Epoch 020 - train 0.14042 | val 3.20894
#   Epoch 021 - train 0.10443 | val 3.37631
#   Classification -> best τ=0.585 (val F1=0.3225)
#   Directional -> Accuracy: 0.4844, MCC: 0.0299, F1: 0.4211
#
# [75/87] Processing TM...
#
# Processing TM (Consumer Goods)...
#   Epoch 010 - train 0.27051 | val 1.63615
#   Epoch 020 - train 0.13021 | val 3.49638
#   Epoch 021 - train 0.11637 | val 3.39748
#   Classification -> best τ=0.430 (val F1=0.5547)
#   Directional -> Accuracy: 0.6562, MCC: 0.2817, F1: 0.7556
#
# [76/87] Processing TOT...
#
# Processing TOT (Basic Matierials)...
#   Epoch 010 - train 0.32444 | val 5.17409
#   Epoch 020 - train 0.16424 | val 10.65968
#   Epoch 021 - train 0.12234 | val 10.99860
#   Classification -> best τ=0.765 (val F1=0.5087)
#   Directional -> Accuracy: 0.6250, MCC: 0.0000, F1: 0.0000
#
# [77/87] Processing TSM...
#
# Processing TSM (Technology)...
#   Epoch 010 - train 0.37144 | val 2.57681
#   Epoch 020 - train 0.15955 | val 2.87463
#   Epoch 021 - train 0.16161 | val 1.84472
#   Classification -> best τ=0.575 (val F1=0.6384)
#   Directional -> Accuracy: 0.6094, MCC: 0.3310, F1: 0.4186
#
# [78/87] Processing UL...
#
# Processing UL (Consumer Goods)...
#   Epoch 010 - train 0.31591 | val 2.75322
#   Epoch 020 - train 0.10003 | val 6.45362
#   Epoch 025 - train 0.05086 | val 7.76324
#   Classification -> best τ=0.950 (val F1=0.5242)
#   Directional -> Accuracy: 0.6094, MCC: 0.2434, F1: 0.4444
#
# [79/87] Processing UN...
#
# Processing UN (Consumer Goods)...
#   Epoch 010 - train 0.25392 | val 3.61321
#   Epoch 020 - train 0.11340 | val 5.96398
#   Epoch 021 - train 0.10648 | val 6.16230
#   Classification -> best τ=0.755 (val F1=0.5477)
#   Directional -> Accuracy: 0.6406, MCC: 0.3731, F1: 0.3784
#
# [80/87] Processing UNH...
#
# Processing UNH (Healthcare)...
#   Epoch 010 - train 0.32083 | val 3.43006
#   Epoch 020 - train 0.16031 | val 6.53333
#   Epoch 022 - train 0.12458 | val 8.09376
#   Classification -> best τ=0.480 (val F1=0.6333)
#   Directional -> Accuracy: 0.6094, MCC: 0.1673, F1: 0.4681
#
# [81/87] Processing UPS...
#
# Processing UPS (Services)...
#   Epoch 010 - train 0.34201 | val 0.89364
#   Epoch 020 - train 0.20210 | val 1.49174
#   Epoch 022 - train 0.14460 | val 1.60436
#   Classification -> best τ=0.635 (val F1=0.6750)
#   Directional -> Accuracy: 0.4844, MCC: -0.2431, F1: 0.0571
#
# [82/87] Processing UTX...
#
# Processing UTX (Industrial Goods)...
#   Epoch 010 - train 0.33691 | val 3.64937
#   Epoch 020 - train 0.15601 | val 5.16307
#   Epoch 021 - train 0.13616 | val 4.85696
#   Classification -> best τ=0.765 (val F1=0.0663)
#   Directional -> Accuracy: 0.4062, MCC: 0.0000, F1: 0.5778
#
# [83/87] Processing V...
#
# Processing V (Financial)...
#   Epoch 010 - train 0.43802 | val 1.35773
#   Epoch 020 - train 0.18036 | val 1.26884
#   Epoch 021 - train 0.17057 | val 1.69453
#   Classification -> best τ=0.225 (val F1=0.3505)
#   Directional -> Accuracy: 0.3750, MCC: -0.3759, F1: 0.5238
#
# [84/87] Processing VZ...
#
# Processing VZ (Technology)...
#   Epoch 010 - train 0.29481 | val 5.36449
#   Epoch 020 - train 0.12693 | val 8.72128
#   Epoch 021 - train 0.11265 | val 10.33839
#   Classification -> best τ=0.875 (val F1=0.4412)
#   Directional -> Accuracy: 0.7188, MCC: 0.4000, F1: 0.7750
#
# [85/87] Processing WFC...
#
# Processing WFC (Financial)...
#   Epoch 010 - train 0.31276 | val 2.18364
#   Epoch 020 - train 0.15358 | val 2.95990
#   Epoch 021 - train 0.13199 | val 2.95404
#   Classification -> best τ=0.625 (val F1=0.3873)
#   Directional -> Accuracy: 0.5938, MCC: 0.2548, F1: 0.5357
#
# [86/87] Processing WMT...
#
# Processing WMT (Services)...
#   Epoch 010 - train 0.33311 | val 3.28165
#   Epoch 020 - train 0.16947 | val 4.11236
#   Epoch 021 - train 0.14148 | val 5.73313
#   Classification -> best τ=0.600 (val F1=0.3234)
#   Directional -> Accuracy: 0.5156, MCC: 0.0355, F1: 0.4918
#
# [87/87] Processing XOM...
#
# Processing XOM (Basic Matierials)...
#   Epoch 010 - train 0.35092 | val 2.07179
#   Epoch 020 - train 0.13313 | val 2.55499
#   Epoch 021 - train 0.12091 | val 2.67895
#   Classification -> best τ=0.600 (val F1=0.4523)
#   Directional -> Accuracy: 0.4219, MCC: 0.0000, F1: 0.0000
#
# ================================================================================
# Pipeline completed: 85/87 companies processed successfully
# ================================================================================
# Skip summary:
#   no_train_window: 2
# ================================================================================
# STOCK PREDICTION PIPELINE RESULTS
# ================================================================================
# Model: GRU | Problem: classification
# Companies analyzed: 85
# Average samples per company: 926
# ==================================================
# OVERALL PERFORMANCE
# ==================================================
# Directional Accuracy:   0.5241 (±0.1041)
# Matthews Correlation:   0.1142 (±0.1851)
# F1 Score:              0.3796 (±0.2239)
# Precision:             0.6306 (±0.2863)
# Recall:                0.4051 (±0.3387)
# ==================================================
# PERFORMANCE BY SECTOR
# ==================================================
# Utilities            | Acc: 0.594±0.068 | MCC: 0.203 | Companies: 10
# Basic Matierials     | Acc: 0.531±0.136 | MCC: 0.043 | Companies: 10
# Consumer Goods       | Acc: 0.530±0.100 | MCC: 0.164 | Companies: 10
# Healthcare           | Acc: 0.520±0.109 | MCC: 0.135 | Companies: 10
# Technology           | Acc: 0.520±0.123 | MCC: 0.149 | Companies: 10
# Financial            | Acc: 0.517±0.108 | MCC: 0.068 | Companies: 10
# Industrial Goods     | Acc: 0.514±0.090 | MCC: 0.138 | Companies: 10
# Services             | Acc: 0.488±0.083 | MCC: 0.098 | Companies: 9
# Conglomerates        | Acc: 0.482±0.113 | MCC: -0.028 | Companies: 6
# ==================================================
# TOP 10 PERFORMERS (by Directional Accuracy)
# ==================================================
# ABBV                 | Healthcare      | Acc: 0.750 | MCC: 0.513
# BBL                  | Basic Matierials | Acc: 0.719 | MCC: 0.224
# SO                   | Utilities       | Acc: 0.719 | MCC: 0.418
# VZ                   | Technology      | Acc: 0.719 | MCC: 0.400
# DUK                  | Utilities       | Acc: 0.672 | MCC: 0.358
# HSBC                 | Financial       | Acc: 0.672 | MCC: 0.416
# RDS-B                | Basic Matierials | Acc: 0.672 | MCC: 0.174
# BSAC                 | Financial       | Acc: 0.656 | MCC: 0.142
# TM                   | Consumer Goods  | Acc: 0.656 | MCC: 0.282
# AEP                  | Utilities       | Acc: 0.641 | MCC: 0.288
# Saved results for GRU to /mnt/primary/benchmarking/meta-results/classification/base
# ========================= RUNNING TOP BiGRU (meta) | 5H =========================
# Pipeline initialized for a 'classification' problem with horizon 5 steps. Device: cuda
# Processing 87 companies with BiGRU model...
# Problem type: classification
# Sequence length: 15
# Features: ['open', 'high', 'low', 'close', 'volume', 'roll_ret_1d', 'roll_ret_5d', 'roll_ret_20d', 'ema_12', 'ema_26', 'ema_50', 'macd_12_26_9', 'macdh_12_26_9', 'macds_12_26_9', 'rsi_14', 'stochrsik_14_14_3_3', 'stochrsid_14_14_3_3', 'atrr_14', 'bb_upper', 'bb_middle', 'bb_lower', 'obv', 'reg_pred_ret_1d_LSTM', 'reg_pred_ret_1d_BiLSTM', 'reg_pred_ret_1d_GRU', 'reg_pred_ret_1d_BiGRU', 'cls_prob_up_1d_LSTM', 'cls_prob_up_1d_BiLSTM', 'cls_prob_up_1d_GRU', 'cls_prob_up_1d_BiGRU']
#
# [1/87] Processing AAPL...
#
# Processing AAPL (Consumer Goods)...
#   Epoch 010 - train 0.38399 | val 1.56545
#   Epoch 011 - train 0.36326 | val 1.81294
#   Classification -> best τ=0.545 (val F1=0.3091)
#   Directional -> Accuracy: 0.5312, MCC: 0.0584, F1: 0.4828
#
# [2/87] Processing ABB...
#
# Processing ABB (Industrial Goods)...
#   Epoch 010 - train 0.40785 | val 7.33143
#   Epoch 011 - train 0.37848 | val 6.74926
#   Classification -> best τ=0.610 (val F1=0.5199)
#   Directional -> Accuracy: 0.6094, MCC: 0.2103, F1: 0.1379
#
# [3/87] Processing ABBV...
#
# Processing ABBV (Healthcare)...
#   Epoch 010 - train 0.38784 | val 2.21988
#   Epoch 012 - train 0.34934 | val 1.21728
#   Classification -> best τ=0.680 (val F1=0.5447)
#   Directional -> Accuracy: 0.7031, MCC: 0.4345, F1: 0.7077
#
# [4/87] Processing AEP...
#
# Processing AEP (Utilities)...
#   Epoch 010 - train 0.34450 | val 0.80220
#   Epoch 012 - train 0.34081 | val 0.92436
#   Classification -> best τ=0.340 (val F1=0.5701)
#   Directional -> Accuracy: 0.7188, MCC: 0.4229, F1: 0.7632
#
# [5/87] Processing AGFS...
#
# Processing AGFS (Conglomerates)...
# No training data in range for AGFS. Skipping...
#
# [6/87] Processing AMGN...
#
# Processing AMGN (Healthcare)...
#   Epoch 010 - train 0.41923 | val 0.66406
#   Epoch 020 - train 0.23805 | val 0.47827
#   Epoch 021 - train 0.27094 | val 0.80771
#   Classification -> best τ=0.115 (val F1=0.7416)
#   Directional -> Accuracy: 0.6250, MCC: 0.3979, F1: 0.5385
#
# [7/87] Processing AMZN...
#
# Processing AMZN (Services)...
#   Epoch 010 - train 0.47372 | val 0.76333
#   Epoch 018 - train 0.34927 | val 2.11142
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fd58894b9a0>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/opt/miniconda3/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1582, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/opt/miniconda3/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/opt/miniconda3/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/opt/miniconda3/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/opt/miniconda3/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt:
#   Classification -> best τ=0.665 (val F1=0.3203)
#   Directional -> Accuracy: 0.3594, MCC: 0.1255, F1: 0.0889
#
# [8/87] Processing BA...
#
# Processing BA (Industrial Goods)...
#   Epoch 010 - train 0.38504 | val 1.26591
#   Epoch 012 - train 0.35637 | val 1.76726
#   Classification -> best τ=0.670 (val F1=0.5546)
#   Directional -> Accuracy: 0.5781, MCC: 0.2361, F1: 0.1818
#
# [9/87] Processing BABA...
#
# Processing BABA (Services)...
# No training data in range for BABA. Skipping...
#
# [10/87] Processing BAC...
#
# Processing BAC (Financial)...
#   Epoch 010 - train 0.44532 | val 0.74688
#   Epoch 011 - train 0.40752 | val 1.27750
#   Classification -> best τ=0.390 (val F1=0.3929)
#   Directional -> Accuracy: 0.5938, MCC: 0.1442, F1: 0.6750
#
# [11/87] Processing BBL...
#
# Processing BBL (Basic Matierials)...
#   Epoch 010 - train 0.41735 | val 2.31189
#   Epoch 011 - train 0.39743 | val 2.95423
#   Classification -> best τ=0.565 (val F1=0.5470)
#   Directional -> Accuracy: 0.5781, MCC: 0.2451, F1: 0.4906
#
# [12/87] Processing BCH...
#
# Processing BCH (Financial)...
#   Epoch 010 - train 0.40607 | val 3.03890
#   Epoch 011 - train 0.36447 | val 3.98232
#   Classification -> best τ=0.500 (val F1=0.4690)
#   Directional -> Accuracy: 0.3906, MCC: 0.1963, F1: 0.5063
#
# [13/87] Processing BHP...
#
# Processing BHP (Basic Matierials)...
#   Epoch 010 - train 0.38120 | val 0.75546
#   Epoch 011 - train 0.35908 | val 0.98533
#   Classification -> best τ=0.550 (val F1=0.4385)
#   Directional -> Accuracy: 0.4375, MCC: 0.1214, F1: 0.4375
#
# [14/87] Processing BP...
#
# Processing BP (Basic Matierials)...
#   Epoch 010 - train 0.41395 | val 0.91055
#   Epoch 011 - train 0.33264 | val 2.02192
#   Classification -> best τ=0.660 (val F1=0.4306)
#   Directional -> Accuracy: 0.6250, MCC: 0.1548, F1: 0.4286
#
# [15/87] Processing BRK-A...
#
# Processing BRK-A (Financial)...
#   Epoch 010 - train 0.42509 | val 2.23579
#   Epoch 011 - train 0.46329 | val 2.67549
#   Classification -> best τ=0.730 (val F1=0.4601)
#   Directional -> Accuracy: 0.5312, MCC: 0.1300, F1: 0.0625
#
# [16/87] Processing BSAC...
#
# Processing BSAC (Financial)...
# Exception ignored in: <function _releaseLock at 0x7fd5ea0dec20>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.10/logging/__init__.py", line 228, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt:
#   Epoch 010 - train 0.37594 | val 4.70417
#   Epoch 011 - train 0.37223 | val 3.51331
#   Classification -> best τ=0.600 (val F1=0.6086)
#   Directional -> Accuracy: 0.7188, MCC: 0.3606, F1: 0.5500
#
# [17/87] Processing BUD...
#
# Processing BUD (Consumer Goods)...
#   Epoch 010 - train 0.39639 | val 4.02035
#   Epoch 011 - train 0.34955 | val 3.88446
#   Classification -> best τ=0.745 (val F1=0.4534)
#   Directional -> Accuracy: 0.3906, MCC: 0.1963, F1: 0.2041
#
# [18/87] Processing C...
#
# Processing C (Financial)...
#   Epoch 010 - train 0.37316 | val 1.89295
#   Epoch 012 - train 0.36853 | val 2.00783
#   Classification -> best τ=0.795 (val F1=0.3340)
#   Directional -> Accuracy: 0.5000, MCC: 0.2019, F1: 0.1579
#
# [19/87] Processing CAT...
#
# Processing CAT (Industrial Goods)...
#   Epoch 010 - train 0.44212 | val 2.27167
#   Epoch 011 - train 0.41080 | val 1.39395
#   Classification -> best τ=0.675 (val F1=0.3934)
#   Directional -> Accuracy: 0.5312, MCC: 0.2149, F1: 0.1667
#
# [20/87] Processing CELG...
#
# Processing CELG (Healthcare)...
#   Epoch 010 - train 0.39748 | val 0.63738
#   Epoch 013 - train 0.36492 | val 0.84064
#   Classification -> best τ=0.340 (val F1=0.7156)
#   Directional -> Accuracy: 0.4844, MCC: 0.0023, F1: 0.3265
#
# [21/87] Processing CHL...
#
# Processing CHL (Technology)...
#   Epoch 010 - train 0.38081 | val 1.99606
#   Epoch 013 - train 0.33409 | val 1.74375
#   Classification -> best τ=0.610 (val F1=0.4811)
#   Directional -> Accuracy: 0.4531, MCC: 0.0404, F1: 0.4444
#
# [22/87] Processing CHTR...
#
# Processing CHTR (Services)...

# %% [markdown]
# # Hyper Parameter Tuning

# %%
# try:
#     import optuna
# except ImportError:
#     import subprocess, sys
#     subprocess.check_call([sys.executable, "-m", "pip", "install", "optuna"])
#     import optuna


# from pathlib import Path
# from datetime import datetime


# def empty_cache():
#     if torch.cuda.is_available():
#         torch.cuda.empty_cache()
#     elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
#         try:
#             torch.mps.empty_cache()
#         except Exception:
#             pass

# # Feature sets
# feature_sets = {
#     'base': feature_columns,
#     'sentiment': feature_columns + sentinemt_columns,
#     'emotion': feature_columns + emotion_columns,
#     'unified_emotion': feature_columns + unified_emotion_columns,
#     'finbert': feature_columns + finbert_columns,
#     'all_nlp': feature_columns + sentinemt_columns + emotion_columns + unified_emotion_columns + stance_columns + finbert_columns,
#     'sector': feature_columns + sector_columns,
#     'sector_sentiment': feature_columns + sector_columns + sentinemt_columns,
#     'sector_emotion': feature_columns + sector_columns + emotion_columns,
#     'sector_unified_emotion': feature_columns + sector_columns + unified_emotion_columns,
#     'sector_finbert': feature_columns + sector_columns + finbert_columns,
#     'sector_all_nlp': feature_columns + sector_columns + sentinemt_columns + emotion_columns + unified_emotion_columns + stance_columns + finbert_columns,
# }

# # Grouping of feature sets to tune
# feature_groups = {
#     'base': ['base'],
#     'nlp': ['sentiment', 'emotion', 'unified_emotion', 'finbert', 'all_nlp'],
#     'sector': ['sector', 'sector_sentiment', 'sector_emotion', 'sector_unified_emotion', 'sector_finbert', 'sector_all_nlp'],
# }

# N_TRIALS = 100
# PROBLEM_TYPES = ['classification', 'regression']

# all_optuna_results = {}

# for problem_type in PROBLEM_TYPES:
#     all_optuna_results[problem_type] = {}
#     for feature_group, group_sets in feature_groups.items():
#         print(f"=== OPTUNA: {problem_type.upper()} | FEATURE GROUP: {feature_group.upper()} ===")
        
#         # Optuna sampler + pruner
#         sampler = optuna.samplers.TPESampler(n_startup_trials=10, multivariate=True, group=True, seed=42)
#         pruner = optuna.pruners.NopPruner()

#         def objective(trial, problem_type=problem_type, group_sets=group_sets):
#             params = {
#                 'problem_type': problem_type,
#                 'feature_set': trial.suggest_categorical('feature_set', list(group_sets)),
#                 'model_type': trial.suggest_categorical('model_type', ['LSTM', 'BiLSTM', 'GRU', 'BiGRU']),
#                 'sequence_length': trial.suggest_int('sequence_length', 5, 20, step=5),
#                 'horizon_steps': trial.suggest_categorical('horizon_steps', [5]),
#                 'hidden1': trial.suggest_categorical('hidden1', [64, 128, 256]),
#                 'hidden2': trial.suggest_categorical('hidden2', [32, 64, 128]),
#                 'num_layers': trial.suggest_categorical('num_layers', [1, 2]),
#                 'inter_rnn_drop': trial.suggest_float('inter_rnn_drop', 0.0, 0.4, step=0.1),
#                 'dropout': trial.suggest_float('dropout', 0.0, 0.8, step=0.1),
#                 'batch_size': trial.suggest_categorical('batch_size', [16, 32, 64]),
#                 'learning_rate': trial.suggest_float('learning_rate', 1e-6, 1e-2, log=True),
#                 'weight_decay': trial.suggest_float('weight_decay', 1e-7, 1e-3, log=True),
#                 'lr_patience': trial.suggest_categorical('lr_patience', [5, 7, 10]),
#                 'lr_factor': trial.suggest_categorical('lr_factor', [0.4, 0.8]),
#                 'early_stopping_patience': trial.suggest_categorical('early_stopping_patience', [10, 15, 20]),
#                 'max_epochs': trial.suggest_categorical('max_epochs', [20, 30, 50]),
#                 'huber_delta': trial.suggest_float('huber_delta', 0.1, 2.0),
#                 'early_stopping_min_delta': trial.suggest_float('early_stopping_min_delta', 0.0, 0.01),
#             }

#             selected_features = feature_sets[params['feature_set']]
#             missing_cols = [c for c in selected_features if c not in master_df.columns]
#             if missing_cols:
#                 print(f"Missing columns for feature_set={params['feature_set']}: {missing_cols}")
#                 return -1.0

#             pipeline = StockPredictionPipeline(
#                 df=master_df,
#                 feature_columns=selected_features,
#                 model_type=params['model_type'],
#                 sequence_length=params['sequence_length'],
#                 problem_type=params['problem_type'],
#                 horizon_steps=params['horizon_steps'],
#                 hidden1=params['hidden1'],
#                 hidden2=params['hidden2'],
#                 num_layers=params['num_layers'],
#                 inter_rnn_drop=params['inter_rnn_drop'],
#                 dropout=params['dropout'],
#                 batch_size=params['batch_size'],
#                 learning_rate=params['learning_rate'],
#                 weight_decay=params['weight_decay'],
#                 lr_patience=params['lr_patience'],
#                 lr_factor=params['lr_factor'],
#                 early_stopping_patience=params['early_stopping_patience'],
#                 max_epochs=params['max_epochs'],
#                 huber_delta=params['huber_delta'],
#                 early_stopping_min_delta=params['early_stopping_min_delta'],
#                 trial=trial
#             )

#             results_df = pipeline.run_pipeline()
#             del pipeline
#             empty_cache()

#             if results_df is None or results_df.empty:
#                 print('[DEBUG] results_df empty or None')
#                 return -1.0

#             # Aggregate validation metrics (classification only)
#             if problem_type == 'classification':
#                 val_f1 = results_df['val_f1'].mean() if 'val_f1' in results_df.columns else float('nan')
#                 if not np.isfinite(val_f1) and 'best_threshold_metric' in results_df.columns:
#                     val_f1 = results_df['best_threshold_metric'].mean()
#                 val_mcc = results_df['val_mcc'].mean() if 'val_mcc' in results_df.columns else float('nan')
#                 val_precision = results_df['val_precision'].mean() if 'val_precision' in results_df.columns else float('nan')
#                 val_recall = results_df['val_recall'].mean() if 'val_recall' in results_df.columns else float('nan')
#                 val_dir_acc = results_df['val_directional_accuracy'].mean() if 'val_directional_accuracy' in results_df.columns else float('nan')

#                 trial.set_user_attr('val_f1', float(val_f1))
#                 trial.set_user_attr('val_mcc', float(val_mcc))
#                 trial.set_user_attr('val_precision', float(val_precision))
#                 trial.set_user_attr('val_recall', float(val_recall))
#                 trial.set_user_attr('val_directional_accuracy', float(val_dir_acc))

#                 score = val_mcc
#                 if not np.isfinite(score):
#                     return -1.0
#                 return float(score)
#             else:
#                 # minimize MAE -> maximize negative MAE
#                 if 'mae' not in results_df.columns:
#                     return -1.0
#                 mae = results_df['mae'].mean()
#                 if not np.isfinite(mae):
#                     return -1.0
#                 return float(-mae)

#         # Run study
#         study = optuna.create_study(direction='maximize', sampler=sampler, pruner=pruner)
#         study.optimize(objective, n_trials=N_TRIALS)

#         # Collect results
#         optuna_results = study.trials_dataframe()
#         user_attrs = pd.DataFrame([t.user_attrs for t in study.trials])
#         optuna_results = pd.concat([optuna_results, user_attrs], axis=1)
#         optuna_results = optuna_results.sort_values('value', ascending=False)
#         all_optuna_results[problem_type][feature_group] = optuna_results

#         out_dir = RESULTS_ROOT / problem_type
#         out_dir.mkdir(parents=True, exist_ok=True)
#         out_path = out_dir / f'optuna_tuning_{feature_group}_5H.csv'
#         optuna_results.to_csv(str(out_path), index=False)
#         print(f'Saved Optuna results to {out_path}')

# # Display latest results (optional)
# all_optuna_results
