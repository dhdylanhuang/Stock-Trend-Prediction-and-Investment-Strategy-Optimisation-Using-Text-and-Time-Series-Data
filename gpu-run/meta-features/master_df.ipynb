# %%
import pandas as pd

# %%
master_df = pd.read_parquet('master_df.parquet')

# %%
print(master_df.shape)
master_df.head()    
master_df.tail()
# Out:
# (108592, 146)
#              date       open       high        low      close  adj_close  \
# 108587 2017-08-28  76.900002  76.940002  76.260002  76.470001  76.470001
# 108588 2017-08-29  76.209999  76.489998  76.080002  76.449997  76.449997
# 108589 2017-08-30  76.239998  76.449997  76.059998  76.099998  76.099998
# 108590 2017-08-31  76.269997  76.489998  76.050003  76.330002  76.330002
# 108591 2017-09-01  76.370003  76.849998  76.320000  76.570000  76.570000
#
#             volume ticker     ema_12     ema_26  ...  cls_correct_GRU  \
# 108587   8229700.0    XOM  77.187452  78.267858  ...              0.0
# 108588   7060400.0    XOM  77.073998  78.133202  ...              0.0
# 108589   8218000.0    XOM  76.924151  77.982594  ...              1.0
# 108590  15641700.0    XOM  76.832744  77.860180  ...              1.0
# 108591   7340800.0    XOM  76.792322  77.764611  ...              1.0
#
#         cls_brier_20_GRU  cls_logloss_20_GRU  cls_acc_20_GRU  cls_brier_BiGRU  \
# ...
